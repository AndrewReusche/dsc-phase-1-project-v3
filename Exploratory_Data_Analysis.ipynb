# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Next I will import the data stored on the .CSV file and save it to a dataframe 

Aviation_Data= pd.read_csv('data/Aviation_Data.csv', low_memory=False)

# %%
#Now I will start exploring the data

Aviation_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90348 entries, 0 to 90347
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      90348 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Latitude                34382 non-null  object
#  7   Longitude               34373 non-null  object
#  8   Airport.Code            50132 non-null  object
#  9   Airport.Name            52704 non-null  object
#  10  Injury.Severity         87889 non-null  object
#  11  Aircraft.damage         85695 non-null  object
#  12  Aircraft.Category       32287 non-null  object
#  13  Registration.Number     87507 non-null  object
# ...

# %%
#taking a look at a sample of the data

Aviation_Data.head()
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
#
#           Location        Country   Latitude   Longitude Airport.Code  \
# 0  MOOSE CREEK, ID  United States        NaN         NaN          NaN
# 1   BRIDGEPORT, CA  United States        NaN         NaN          NaN
# 2    Saltville, VA  United States  36.922223  -81.878056          NaN
# 3       EUREKA, CA  United States        NaN         NaN          NaN
# 4       Canton, OH  United States        NaN         NaN          NaN
#
#   Airport.Name  ... Purpose.of.flight Air.carrier Total.Fatal.Injuries  \
# 0          NaN  ...          Personal         NaN                  2.0
# ...

# %%
Aviation_Data['Total.Fatal.Injuries'].value_counts()
# Out:
# Total.Fatal.Injuries
# 0.0      59675
# 1.0       8883
# 2.0       5173
# 3.0       1589
# 4.0       1103
#          ...
# 156.0        1
# 68.0         1
# 31.0         1
# 115.0        1
# 176.0        1
# Name: count, Length: 125, dtype: int64

# %%
#see if there are re-occuring event id's
Aviation_Data['Event.Id'].value_counts()
# Out:
# Event.Id
# 20001212X19172    3
# 20001214X45071    3
# 20220730105623    2
# 20051213X01965    2
# 20001212X16765    2
#                  ..
# 20001211X14216    1
# 20001211X14239    1
# 20001211X14207    1
# 20001211X14204    1
# 20221230106513    1
# Name: count, Length: 87951, dtype: int64

# %%
Aviation_Data['Number.of.Engines'].value_counts()
# Out:
# Number.of.Engines
# 1.0    69582
# 2.0    11079
# 0.0     1226
# 3.0      483
# 4.0      431
# 8.0        3
# 6.0        1
# Name: count, dtype: int64

# %%
Aviation_Data['Engine.Type'].value_counts()
# Out:
# Engine.Type
# Reciprocating      69530
# Turbo Shaft         3609
# Turbo Prop          3391
# Turbo Fan           2481
# Unknown             2051
# Turbo Jet            703
# Geared Turbofan       12
# Electric              10
# LR                     2
# NONE                   2
# Hybrid Rocket          1
# UNK                    1
# Name: count, dtype: int64

# %%
Aviation_Data['Accident.Number'].value_counts()
# Out:
# Accident.Number
# CEN22LA149    2
# WPR23LA041    2
# WPR23LA045    2
# DCA22WA214    2
# DCA22WA089    2
#              ..
# LAX92FA065    1
# ANC92T#A12    1
# MIA92LA049    1
# NYC92LA048    1
# ERA23LA097    1
# Name: count, Length: 88863, dtype: int64

# %%
Aviation_Data['Injury.Severity'].value_counts()
# Out:
# Injury.Severity
# Non-Fatal     67357
# Fatal(1)       6167
# Fatal          5262
# Fatal(2)       3711
# Incident       2219
#               ...
# Fatal(270)        1
# Fatal(60)         1
# Fatal(43)         1
# Fatal(143)        1
# Fatal(230)        1
# Name: count, Length: 109, dtype: int64

# %%
Aviation_Data['Aircraft.Category'].value_counts()
# Out:
# Aircraft.Category
# Airplane             27617
# Helicopter            3440
# Glider                 508
# Balloon                231
# Gyrocraft              173
# Weight-Shift           161
# Powered Parachute       91
# Ultralight              30
# Unknown                 14
# WSFT                     9
# Powered-Lift             5
# Blimp                    4
# UNK                      2
# Rocket                   1
# ULTR                     1
# Name: count, dtype: int64

# %%
Aviation_Data['Make'].value_counts()
# Out:
# Make
# Cessna             22227
# Piper              12029
# CESSNA              4922
# Beech               4330
# PIPER               2841
#                    ...
# Leonard Walters        1
# Maule Air Inc.         1
# Motley Vans            1
# Perlick                1
# ROYSE RALPH L          1
# Name: count, Length: 8237, dtype: int64

# %%
Aviation_Data['Model'].value_counts()
# Out:
# Model
# 152              2367
# 172              1756
# 172N             1164
# PA-28-140         932
# 150               829
#                  ...
# GC-1-A              1
# 737-3S3             1
# MBB-BK117-B2        1
# GLASSAIR GL25       1
# M-8 EAGLE           1
# Name: count, Length: 12318, dtype: int64

# %%
Aviation_Data['Amateur.Built'].value_counts()
# Out:
# Amateur.Built
# No     80312
# Yes     8475
# Name: count, dtype: int64

# %%
Aviation_Data['Total.Fatal.Injuries'].value_counts()
# Out:
# Total.Fatal.Injuries
# 0.0      59675
# 1.0       8883
# 2.0       5173
# 3.0       1589
# 4.0       1103
#          ...
# 156.0        1
# 68.0         1
# 31.0         1
# 115.0        1
# 176.0        1
# Name: count, Length: 125, dtype: int64

# %%
Aviation_Data['Total.Serious.Injuries'].value_counts()
# Out:
# Total.Serious.Injuries
# 0.0      63289
# 1.0       9125
# 2.0       2815
# 3.0        629
# 4.0        258
# 5.0         78
# 6.0         41
# 7.0         27
# 9.0         16
# 10.0        13
# 8.0         13
# 13.0         9
# 11.0         6
# 26.0         5
# 14.0         5
# 12.0         5
# 20.0         3
# 25.0         3
# 28.0         3
# 21.0         2
# 59.0         2
# 50.0         2
# 17.0         2
# 47.0         2
# 137.0        1
# 19.0         1
# 161.0        1
# 27.0         1
# 35.0         1
# 67.0         1
# 33.0         1
# 88.0         1
# 125.0        1
# 53.0         1
# 34.0         1
# 41.0         1
# 18.0         1
# 63.0         1
# 55.0         1
# 23.0         1
# 43.0         1
# 39.0         1
# 45.0         1
# 44.0         1
# 16.0         1
# 60.0         1
# 106.0        1
# 81.0         1
# 15.0         1
# 22.0         1
# Name: count, dtype: int64

# %%
Aviation_Data['Total.Minor.Injuries'].value_counts()
# Out:
# Total.Minor.Injuries
# 0.0      61454
# 1.0      10320
# 2.0       3576
# 3.0        784
# 4.0        372
# 5.0        129
# 6.0         67
# 7.0         59
# 9.0         22
# 8.0         20
# 13.0        14
# 10.0        11
# 12.0        11
# 14.0        10
# 11.0         9
# 17.0         8
# 19.0         6
# 18.0         6
# 24.0         5
# 22.0         5
# 25.0         4
# 16.0         4
# 15.0         4
# 33.0         4
# 20.0         3
# 21.0         3
# 26.0         3
# 23.0         3
# 32.0         3
# 27.0         3
# 50.0         2
# 30.0         2
# 36.0         2
# 31.0         2
# 28.0         2
# 42.0         2
# 38.0         2
# 57.0         1
# 65.0         1
# 84.0         1
# 43.0         1
# 35.0         1
# 380.0        1
# 47.0         1
# 68.0         1
# 200.0        1
# 71.0         1
# 58.0         1
# 171.0        1
# 39.0         1
# 96.0         1
# 29.0         1
# 69.0         1
# 62.0         1
# 45.0         1
# 125.0        1
# 40.0         1
# ...

# %%
Aviation_Data['Total.Uninjured'].value_counts()
# Out:
# Total.Uninjured
# 0.0      29879
# 1.0      25101
# 2.0      15988
# 3.0       4313
# 4.0       2662
#          ...
# 558.0        1
# 412.0        1
# 338.0        1
# 401.0        1
# 455.0        1
# Name: count, Length: 379, dtype: int64

# %%
Aviation_Data['Country'].value_counts()
# Out:
# Country
# United States                       82248
# Brazil                                374
# Canada                                359
# Mexico                                358
# United Kingdom                        344
#                                     ...
# Seychelles                              1
# Palau                                   1
# Libya                                   1
# Saint Vincent and the Grenadines        1
# Turks and Caicos Islands                1
# Name: count, Length: 219, dtype: int64

# %%
Aviation_Data['Weather.Condition'].value_counts()
# Out:
# Weather.Condition
# VMC    77303
# IMC     5976
# UNK      856
# Unk      262
# Name: count, dtype: int64

# %%
##create a new dataframe from the columns that you want to keep

# %%
#see what columns you have currently

# %%
Aviation_Data.columns
# Out:
# Index(['Event.Id', 'Investigation.Type', 'Accident.Number', 'Event.Date',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Airport.Code',
#        'Airport.Name', 'Injury.Severity', 'Aircraft.damage',
#        'Aircraft.Category', 'Registration.Number', 'Make', 'Model',
#        'Amateur.Built', 'Number.of.Engines', 'Engine.Type', 'FAR.Description',
#        'Schedule', 'Purpose.of.flight', 'Air.carrier', 'Total.Fatal.Injuries',
#        'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured',
#        'Weather.Condition', 'Broad.phase.of.flight', 'Report.Status',
#        'Publication.Date'],
#       dtype='object')

# %%
stripped_data=Aviation_Data[['Event.Id','Accident.Number','Aircraft.Category',
                             'Amateur.Built',
                             'Make','Model','Number.of.Engines','Engine.Type',
                             'Purpose.of.flight', 'Total.Fatal.Injuries', 'Total.Serious.Injuries', 
                             'Total.Minor.Injuries', 'Total.Uninjured','Event.Date','Location',
                             'Country','Weather.Condition']].copy()

# %%
stripped_data.head()
# Out:
#          Event.Id Accident.Number Aircraft.Category Amateur.Built      Make  \
# 0  20001218X45444      SEA87LA080               NaN            No   Stinson
# 1  20001218X45447      LAX94LA336               NaN            No     Piper
# 2  20061025X01555      NYC07LA005               NaN            No    Cessna
# 3  20001218X45448      LAX96LA321               NaN            No  Rockwell
# 4  20041105X01764      CHI79FA064               NaN            No    Cessna
#
#       Model  Number.of.Engines    Engine.Type Purpose.of.flight  \
# 0     108-3                1.0  Reciprocating          Personal
# 1  PA24-180                1.0  Reciprocating          Personal
# 2      172M                1.0  Reciprocating          Personal
# 3       112                1.0  Reciprocating          Personal
# 4       501                NaN            NaN          Personal
#
#    Total.Fatal.Injuries  Total.Serious.Injuries  Total.Minor.Injuries  \
# ...

# %%
stripped_data['Make']= stripped_data['Make'].str.title()

# %%
stripped_data['Model']= stripped_data['Model'].str.title()

# %%
stripped_data['Weather.Condition']= stripped_data['Weather.Condition'].str.title()

# %%
stripped_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90348 entries, 0 to 90347
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Accident.Number         88889 non-null  object
#  2   Aircraft.Category       32287 non-null  object
#  3   Amateur.Built           88787 non-null  object
#  4   Make                    88826 non-null  object
#  5   Model                   88797 non-null  object
#  6   Number.of.Engines       82805 non-null  float64
#  7   Engine.Type             81793 non-null  object
#  8   Purpose.of.flight       82697 non-null  object
#  9   Total.Fatal.Injuries    77488 non-null  float64
#  10  Total.Serious.Injuries  76379 non-null  float64
#  11  Total.Minor.Injuries    76956 non-null  float64
#  12  Total.Uninjured         82977 non-null  float64
#  13  Event.Date              88889 non-null  object
# ...

# %%
stripped_data['Weather.Condition'].value_counts()
# Out:
# Weather.Condition
# Vmc    77303
# Imc     5976
# Unk     1118
# Name: count, dtype: int64

# %%
aircraft_data= stripped_data[stripped_data['Aircraft.Category']== 'Airplane']

# %%
aircraft_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27617 entries, 5 to 90345
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                27617 non-null  object
#  1   Accident.Number         27617 non-null  object
#  2   Aircraft.Category       27617 non-null  object
#  3   Amateur.Built           27600 non-null  object
#  4   Make                    27608 non-null  object
#  5   Model                   27586 non-null  object
#  6   Number.of.Engines       24863 non-null  float64
#  7   Engine.Type             23391 non-null  object
#  8   Purpose.of.flight       23878 non-null  object
#  9   Total.Fatal.Injuries    24452 non-null  float64
#  10  Total.Serious.Injuries  24393 non-null  float64
#  11  Total.Minor.Injuries    24739 non-null  float64
#  12  Total.Uninjured         26717 non-null  float64
#  13  Event.Date              27617 non-null  object
# ...

# %%
aircraft_data= aircraft_data[aircraft_data['Country']== 'United States']

# %%
aircraft_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24229 entries, 5 to 90345
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                24229 non-null  object
#  1   Accident.Number         24229 non-null  object
#  2   Aircraft.Category       24229 non-null  object
#  3   Amateur.Built           24225 non-null  object
#  4   Make                    24223 non-null  object
#  5   Model                   24210 non-null  object
#  6   Number.of.Engines       23607 non-null  float64
#  7   Engine.Type             22360 non-null  object
#  8   Purpose.of.flight       22999 non-null  object
#  9   Total.Fatal.Injuries    21268 non-null  float64
#  10  Total.Serious.Injuries  21288 non-null  float64
#  11  Total.Minor.Injuries    21633 non-null  float64
#  12  Total.Uninjured         23514 non-null  float64
#  13  Event.Date              24229 non-null  object
# ...

# %%
#pro_aircraft_data refers to professional aircraft data, as in
#aircrafts that are not amateur built

pro_aircraft_data= aircraft_data[aircraft_data['Amateur.Built']== 'No']

# %%
pro_aircraft_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21121 entries, 5 to 90345
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                21121 non-null  object
#  1   Accident.Number         21121 non-null  object
#  2   Aircraft.Category       21121 non-null  object
#  3   Amateur.Built           21121 non-null  object
#  4   Make                    21121 non-null  object
#  5   Model                   21115 non-null  object
#  6   Number.of.Engines       20637 non-null  float64
#  7   Engine.Type             19468 non-null  object
#  8   Purpose.of.flight       19893 non-null  object
#  9   Total.Fatal.Injuries    18536 non-null  float64
#  10  Total.Serious.Injuries  18528 non-null  float64
#  11  Total.Minor.Injuries    18814 non-null  float64
#  12  Total.Uninjured         20563 non-null  float64
#  13  Event.Date              21121 non-null  object
# ...

# %%
pro_aircraft_data.duplicated().value_counts()
# Out:
# False    21120
# True         1
# Name: count, dtype: int64

# %%
pro_aircraft_data[pro_aircraft_data.duplicated()]
# Out:
#              Event.Id Accident.Number Aircraft.Category Amateur.Built    Make  \
# 89830  20220822105776      ERA22LA379          Airplane            No  Boeing
#
#        Model  Number.of.Engines Engine.Type Purpose.of.flight  \
# 89830  A75N1                1.0         NaN          Business
#
#        Total.Fatal.Injuries  Total.Serious.Injuries  Total.Minor.Injuries  \
# 89830                   0.0                     2.0                   0.0
#
#        Total.Uninjured  Event.Date      Location        Country  \
# 89830              2.0  2022-08-20  Bealeton, VA  United States
#
#       Weather.Condition
# 89830               Vmc

# %%
#there are 1,460 duplicate values in the dataframe.
#if these were actual duplicated values instead of missing values (NAN)
#this could cause a bias in any analysis we use. This data will not 
#have any positive contibution to any analysis we do so we will get rid
#of the duplicates and store the cleaned data in a new Dataframe

# %%
#strip the duplicate lines from the data, and store it in a new dataframe

# %%
pro_aircraft_data= pro_aircraft_data.drop_duplicates()

# %%
#confirm the duped data has been dropped
pro_aircraft_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21120 entries, 5 to 90345
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                21120 non-null  object
#  1   Accident.Number         21120 non-null  object
#  2   Aircraft.Category       21120 non-null  object
#  3   Amateur.Built           21120 non-null  object
#  4   Make                    21120 non-null  object
#  5   Model                   21114 non-null  object
#  6   Number.of.Engines       20636 non-null  float64
#  7   Engine.Type             19468 non-null  object
#  8   Purpose.of.flight       19892 non-null  object
#  9   Total.Fatal.Injuries    18535 non-null  float64
#  10  Total.Serious.Injuries  18527 non-null  float64
#  11  Total.Minor.Injuries    18813 non-null  float64
#  12  Total.Uninjured         20562 non-null  float64
#  13  Event.Date              21120 non-null  object
# ...

# %%
pro_aircraft_data.head()
# Out:
#           Event.Id Accident.Number Aircraft.Category Amateur.Built  \
# 5   20170710X52551      NYC79AA106          Airplane            No
# 7   20020909X01562      SEA82DA022          Airplane            No
# 8   20020909X01561      NYC82DA015          Airplane            No
# 12  20020917X02148      FTW82FRJ07          Airplane            No
# 13  20020917X02134      FTW82FRA14          Airplane            No
#
#                  Make   Model  Number.of.Engines    Engine.Type  \
# 5   Mcdonnell Douglas     Dc9                2.0      Turbo Fan
# 7              Cessna     140                1.0  Reciprocating
# 8              Cessna    401B                2.0  Reciprocating
# 12           Bellanca  17-30A                1.0  Reciprocating
# 13             Cessna   R172K                1.0  Reciprocating
#
#    Purpose.of.flight  Total.Fatal.Injuries  Total.Serious.Injuries  \
# 5                NaN                   NaN                     NaN
# ...

# %%
pro_aircraft_data['Total.Fatal.Injuries'].value_counts()
# Out:
# Total.Fatal.Injuries
# 0.0      15370
# 1.0       1613
# 2.0        941
# 3.0        283
# 4.0        187
# 5.0         58
# 6.0         32
# 7.0         15
# 8.0         10
# 10.0         8
# 9.0          4
# 12.0         3
# 14.0         2
# 11.0         2
# 17.0         1
# 27.0         1
# 16.0         1
# 228.0        1
# 65.0         1
# 13.0         1
# 49.0         1
# Name: count, dtype: int64

# %%
pro_aircraft_data[pro_aircraft_data['Total.Fatal.Injuries'].isna()]
# Out:
#              Event.Id Accident.Number Aircraft.Category Amateur.Built  \
# 5      20170710X52551      NYC79AA106          Airplane            No
# 260    20020917X02495      NYC82DA033          Airplane            No
# 351    20020917X02151      FTW82IA062          Airplane            No
# 801    20020917X01772      ATL82LA098          Airplane            No
# 1164   20020917X03106      DCA82IA021          Airplane            No
# ...               ...             ...               ...           ...
# 63901  20080111X00041      DFW08CA051          Airplane            No
# 63903  20080129X00118      DEN08CA045          Airplane            No
# 63904  20080215X00200      CHI08CA058          Airplane            No
# 63905  20080214X00193      CHI08CA056          Airplane            No
# 63911  20080125X00106      SEA08CA056          Airplane            No
#
#                                  Make       Model  Number.of.Engines  \
# ...

# %%
#after reviewing the columns with NAN in the injury columns we can tell that 
#just because the Total Fatal Injuries column may be missing data doesn't mean
#column is totaly useless. In fact in can point to their being non fatal or
#no injuries in the incident. Being that this is the case, we will only get rid of all
#the columns that have NAN across all of the injury counted rows.

#make a dataset that gets rid of all columns that have NAN
#across all injuries columns

# %%
#cleaned_pro_aircraft_data
c_pro_aircraft_data=pro_aircraft_data.dropna(subset=['Total.Fatal.Injuries',
                                                 'Total.Serious.Injuries'\
                                                 ,'Total.Uninjured'],
                                         how='all').copy()

# %%
c_pro_aircraft_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20808 entries, 5 to 90345
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                20808 non-null  object
#  1   Accident.Number         20808 non-null  object
#  2   Aircraft.Category       20808 non-null  object
#  3   Amateur.Built           20808 non-null  object
#  4   Make                    20808 non-null  object
#  5   Model                   20804 non-null  object
#  6   Number.of.Engines       20324 non-null  float64
#  7   Engine.Type             19158 non-null  object
#  8   Purpose.of.flight       19583 non-null  object
#  9   Total.Fatal.Injuries    18535 non-null  float64
#  10  Total.Serious.Injuries  18527 non-null  float64
#  11  Total.Minor.Injuries    18504 non-null  float64
#  12  Total.Uninjured         20562 non-null  float64
#  13  Event.Date              20808 non-null  object
# ...

# %%
#lets create a new column named 'Fatal Flight?' that simply calls 
#out if an incident had a fatal result or not. We can do this by 
#saying 'Fatal' if the value in Total.Fatal.Injuries column >= 1. 
#If this value is not >= 1 then the new column will display 
#'Not Fatal'

# %%
#We will be able to use this column to do different analyses on
#the safety of the different flying vehicles. In these analyses, 
#safety is denoted by whether a flight was fatal or not.

# %%
#the new column will be called 'incident severity'

# %%
c_pro_aircraft_data['Incident.Severity']=c_pro_aircraft_data\
['Total.Fatal.Injuries'].map(lambda x: 1 if x >= 1 else 0)

# %%
c_pro_aircraft_data.head()
# Out:
#           Event.Id Accident.Number Aircraft.Category Amateur.Built  \
# 5   20170710X52551      NYC79AA106          Airplane            No
# 7   20020909X01562      SEA82DA022          Airplane            No
# 8   20020909X01561      NYC82DA015          Airplane            No
# 12  20020917X02148      FTW82FRJ07          Airplane            No
# 13  20020917X02134      FTW82FRA14          Airplane            No
#
#                  Make   Model  Number.of.Engines    Engine.Type  \
# 5   Mcdonnell Douglas     Dc9                2.0      Turbo Fan
# 7              Cessna     140                1.0  Reciprocating
# 8              Cessna    401B                2.0  Reciprocating
# 12           Bellanca  17-30A                1.0  Reciprocating
# 13             Cessna   R172K                1.0  Reciprocating
#
#    Purpose.of.flight  Total.Fatal.Injuries  Total.Serious.Injuries  \
# 5                NaN                   NaN                     NaN
# ...

# %%
c_pro_aircraft_data['Incident.Severity'].value_counts()
# Out:
# Incident.Severity
# 0    17643
# 1     3165
# Name: count, dtype: int64

# %%
##now that I have created a df with the new column that I would like I need to split that
#dataframe into three new dataframes for analysis

# %%
#the first dataframe will compare different types of engines to see which ones have the
#lowest associated fatality rates

# %%
#the second dataframe will compare the number of engines types of engines to see if the 
#number of engines effects the fatality rate

# %%
#the third dataframe will compare the model of the flying vehicles to 
#see which of those have the lowest fatality rate

# %%
#lets start transforming the data into a engine type data set and then cleaning it

# %%
c_pro_aircraft_data.columns
# Out:
# Index(['Event.Id', 'Accident.Number', 'Aircraft.Category', 'Amateur.Built',
#        'Make', 'Model', 'Number.of.Engines', 'Engine.Type',
#        'Purpose.of.flight', 'Total.Fatal.Injuries', 'Total.Serious.Injuries',
#        'Total.Minor.Injuries', 'Total.Uninjured', 'Event.Date', 'Location',
#        'Country', 'Weather.Condition', 'Incident.Severity'],
#       dtype='object')

# %%
Engine_Type=c_pro_aircraft_data[['Event.Id', 'Accident.Number'\
                                 , 'Engine.Type', \
                                 'Incident.Severity']].copy()

# %%
#now lets explore this new df to see the best way to clean it

# %%
Engine_Type[Engine_Type.duplicated]
# Out:
#              Event.Id Accident.Number    Engine.Type  Incident.Severity
# 88568  20220111104514      ERA22LA103  Reciprocating                  0
# 88695  20220212104630      ERA22LA119  Reciprocating                  0
# 89300  20220614105258      DCA22WA130            NaN                  0
# 89384  20220623105317      DCA22LA135            NaN                  0
# 89594  20220718105496      ERA22FA318            NaN                  1
# 89668  20220727105589      ERA22FA338            NaN                  1
# 89751  20220808105682      ERA22LA364            NaN                  0
# 89814  20220818105763      WPR22FA309            NaN                  1
# 90236  20221112106276      CEN23MA034            NaN                  1

# %%
Engine_Type.drop_duplicates(inplace=True)

# %%
#since there are not any repeat Event Id's and Accident numbers that 
#can help us interprat what the NAN might be
#the best way to mitigate the bias in analysis would be to delete them
#instead of imputing them

# %%
#cleaned_engine_type
C_Engine_Type=Engine_Type.dropna(subset=['Engine.Type']).copy()

# %%
C_Engine_Type.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19156 entries, 5 to 90226
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Event.Id           19156 non-null  object
#  1   Accident.Number    19156 non-null  object
#  2   Engine.Type        19156 non-null  object
#  3   Incident.Severity  19156 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 748.3+ KB

# %%
#this new dataframe is now ready for analysis

# %%
#Start by grouping Incident Severity by Engine Type

# %%
Engine_Count_Series=C_Engine_Type.groupby(['Engine.Type'])\
['Incident.Severity'].sum()

# %%
#convert this series to a datadrame

# %%
Engine_Fatality_Count=Engine_Count_Series.to_frame()

# %%
Engine_Fatality_Count
# Out:
#                Incident.Severity
# Engine.Type
# Electric                       0
# Reciprocating               2475
# Turbo Fan                     48
# Turbo Jet                     23
# Turbo Prop                   247
# Turbo Shaft                    1
# UNK                            0
# Unknown                        2

# %%
#rename the count column

# %%
Engine_Fatality_Count.rename(columns={'Incident.Severity':\
    'Fatality.Count'},inplace=True)

# %%
Engine_Fatality_Count
# Out:
#                Fatality.Count
# Engine.Type
# Electric                    0
# Reciprocating            2475
# Turbo Fan                  48
# Turbo Jet                  23
# Turbo Prop                247
# Turbo Shaft                 1
# UNK                         0
# Unknown                     2

# %%
#compare these numbers to the total instances of each type of motor

# %%
Engine_Type_Count_Series=C_Engine_Type['Engine.Type'].value_counts()

# %%
#convert this series to a dataframe
Engine_Count=Engine_Type_Count_Series.to_frame()

# %%
Engine_Count
# Out:
#                count
# Engine.Type
# Reciprocating  17091
# Turbo Prop      1198
# Turbo Fan        698
# Turbo Jet        140
# Unknown           14
# Turbo Shaft        9
# Electric           5
# UNK                1

# %%
#rename the count column
Engine_Count.rename(columns={'count': 'Incident.Count'},inplace=True)

# %%
Engine_Count
# Out:
#                Incident.Count
# Engine.Type
# Reciprocating           17091
# Turbo Prop               1198
# Turbo Fan                 698
# Turbo Jet                 140
# Unknown                    14
# Turbo Shaft                 9
# Electric                    5
# UNK                         1

# %%
#Merge the two new DataFrames along the shared index
Engine_Fatality_Analysis=Engine_Fatality_Count.join(Engine_Count, how='inner')
Engine_Fatality_Analysis
# Out:
#                Fatality.Count  Incident.Count
# Engine.Type
# Electric                    0               5
# Reciprocating            2475           17091
# Turbo Fan                  48             698
# Turbo Jet                  23             140
# Turbo Prop                247            1198
# Turbo Shaft                 1               9
# UNK                         0               1
# Unknown                     2              14

# %%
#get rid of the unknown column rows: UNK and Unknown
#get rid of the columns with insignificant amounts of data
Engine_Fatality_Analysis.drop(index={'Unknown', 'UNK', 'Electric',\
                                'Turbo Shaft'},\
                              inplace=True)

Engine_Fatality_Analysis
# Out:
#                Fatality.Count  Incident.Count
# Engine.Type
# Reciprocating            2475           17091
# Turbo Fan                  48             698
# Turbo Jet                  23             140
# Turbo Prop                247            1198

# %%
Engine_Type_Analysis= Engine_Fatality_Analysis

# %%
Engine_Type_Analysis.reset_index(inplace=True)

Engine_Type_Analysis
# Out:
#      Engine.Type  Fatality.Count  Incident.Count
# 0  Reciprocating            2475           17091
# 1      Turbo Fan              48             698
# 2      Turbo Jet              23             140
# 3     Turbo Prop             247            1198

# %%
##Now to conduct the same data manipulation and dataframe creation for
#number of engines vs Fatalities

# %%
c_pro_aircraft_data.columns
# Out:
# Index(['Event.Id', 'Accident.Number', 'Aircraft.Category', 'Amateur.Built',
#        'Make', 'Model', 'Number.of.Engines', 'Engine.Type',
#        'Purpose.of.flight', 'Total.Fatal.Injuries', 'Total.Serious.Injuries',
#        'Total.Minor.Injuries', 'Total.Uninjured', 'Event.Date', 'Location',
#        'Country', 'Weather.Condition', 'Incident.Severity'],
#       dtype='object')

# %%
Engine_Count=c_pro_aircraft_data[['Event.Id','Accident.Number',\
                                  'Number.of.Engines',\
                                  'Incident.Severity']].copy()

Engine_Count.head()
# Out:
#           Event.Id Accident.Number  Number.of.Engines  Incident.Severity
# 5   20170710X52551      NYC79AA106                2.0                  0
# 7   20020909X01562      SEA82DA022                1.0                  0
# 8   20020909X01561      NYC82DA015                2.0                  0
# 12  20020917X02148      FTW82FRJ07                1.0                  0
# 13  20020917X02134      FTW82FRA14                1.0                  1

# %%
Engine_Count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20808 entries, 5 to 90345
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Event.Id           20808 non-null  object
#  1   Accident.Number    20808 non-null  object
#  2   Number.of.Engines  20324 non-null  float64
#  3   Incident.Severity  20808 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 812.8+ KB

# %%
C_Engine_Count= Engine_Count.dropna(subset=['Number.of.Engines']).copy()
C_Engine_Count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20324 entries, 5 to 90345
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Event.Id           20324 non-null  object
#  1   Accident.Number    20324 non-null  object
#  2   Number.of.Engines  20324 non-null  float64
#  3   Incident.Severity  20324 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 793.9+ KB

# %%
C_Engine_Count[C_Engine_Count.duplicated]
# Out:
#              Event.Id Accident.Number  Number.of.Engines  Incident.Severity
# 88568  20220111104514      ERA22LA103                1.0                  0
# 88695  20220212104630      ERA22LA119                1.0                  0
# 88856  20220323104818      CEN22LA149                1.0                  0
# 89384  20220623105317      DCA22LA135                2.0                  0
# 89594  20220718105496      ERA22FA318                1.0                  1
# 89668  20220727105589      ERA22FA338                1.0                  1
# 89751  20220808105682      ERA22LA364                1.0                  0

# %%
C_Engine_Count.drop_duplicates(inplace=True)

# %%
Engine_Count_Series=C_Engine_Count.groupby(['Number.of.Engines'])\
                    ['Incident.Severity'].sum()
Engine_Count_Series
# Out:
# Number.of.Engines
# 0.0       0
# 1.0    2477
# 2.0     567
# 3.0       2
# 4.0      11
# 6.0       0
# 8.0       0
# Name: Incident.Severity, dtype: int64

# %%
Num_of_Fatal_Engine_Count=Engine_Count_Series.to_frame()
Num_of_Fatal_Engine_Count
# Out:
#                    Incident.Severity
# Number.of.Engines
# 0.0                                0
# 1.0                             2477
# 2.0                              567
# 3.0                                2
# 4.0                               11
# 6.0                                0
# 8.0                                0

# %%
Num_of_Fatal_Engine_Count.rename(columns={'Incident.Severity':\
                                          'Fatality.Count'},inplace=True)

Num_of_Fatal_Engine_Count
# Out:
#                    Fatality.Count
# Number.of.Engines
# 0.0                             0
# 1.0                          2477
# 2.0                           567
# 3.0                             2
# 4.0                            11
# 6.0                             0
# 8.0                             0

# %%
Engine_Count_Series=C_Engine_Count['Number.of.Engines'].value_counts()
Engine_Count_Series
# Out:
# Number.of.Engines
# 1.0    17383
# 2.0     2832
# 4.0       52
# 3.0       44
# 0.0        4
# 8.0        1
# 6.0        1
# Name: count, dtype: int64

# %%
Total_Engines_Count=Engine_Count_Series.to_frame()
Total_Engines_Count
# Out:
#                    count
# Number.of.Engines
# 1.0                17383
# 2.0                 2832
# 4.0                   52
# 3.0                   44
# 0.0                    4
# 8.0                    1
# 6.0                    1

# %%
Total_Engines_Count.rename(columns={'count': 'Incident.Count'},inplace=True)
Total_Engines_Count
# Out:
#                    Incident.Count
# Number.of.Engines
# 1.0                         17383
# 2.0                          2832
# 4.0                            52
# 3.0                            44
# 0.0                             4
# 8.0                             1
# 6.0                             1

# %%
Number_of_Engine_Analysis=Num_of_Fatal_Engine_Count.join(\
                        Total_Engines_Count, how='inner')
Number_of_Engine_Analysis
# Out:
#                    Fatality.Count  Incident.Count
# Number.of.Engines
# 0.0                             0               4
# 1.0                          2477           17383
# 2.0                           567            2832
# 3.0                             2              44
# 4.0                            11              52
# 6.0                             0               1
# 8.0                             0               1

# %%
#get rid of the columns with insignificant amounts of data
Number_of_Engine_Analysis.drop(index={0.0, 6.0, 8.0},\
                              inplace=True)

Number_of_Engine_Analysis
# Out:
#                    Fatality.Count  Incident.Count
# Number.of.Engines
# 1.0                          2477           17383
# 2.0                           567            2832
# 3.0                             2              44
# 4.0                            11              52

# %%
Number_of_Engine_Analysis.index=Number_of_Engine_Analysis.index.astype(str)

Number_of_Engine_Analysis
# Out:
#                    Fatality.Count  Incident.Count
# Number.of.Engines
# 1.0                          2477           17383
# 2.0                           567            2832
# 3.0                             2              44
# 4.0                            11              52

# %%
###now lets do the same for model fatality analysis

# %%
c_pro_aircraft_data.columns
# Out:
# Index(['Event.Id', 'Accident.Number', 'Aircraft.Category', 'Amateur.Built',
#        'Make', 'Model', 'Number.of.Engines', 'Engine.Type',
#        'Purpose.of.flight', 'Total.Fatal.Injuries', 'Total.Serious.Injuries',
#        'Total.Minor.Injuries', 'Total.Uninjured', 'Event.Date', 'Location',
#        'Country', 'Weather.Condition', 'Incident.Severity'],
#       dtype='object')

# %%
Fatal_Model_Count=c_pro_aircraft_data[['Event.Id','Accident.Number',\
                                       'Model','Incident.Severity']].copy()

Fatal_Model_Count.head()
# Out:
#           Event.Id Accident.Number   Model  Incident.Severity
# 5   20170710X52551      NYC79AA106     Dc9                  0
# 7   20020909X01562      SEA82DA022     140                  0
# 8   20020909X01561      NYC82DA015    401B                  0
# 12  20020917X02148      FTW82FRJ07  17-30A                  0
# 13  20020917X02134      FTW82FRA14   R172K                  1

# %%
Fatal_Model_Count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20808 entries, 5 to 90345
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Event.Id           20808 non-null  object
#  1   Accident.Number    20808 non-null  object
#  2   Model              20804 non-null  object
#  3   Incident.Severity  20808 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 812.8+ KB

# %%
Fatal_Model_Count.sort_values(['Event.Id','Accident.Number']).asceding=(True)
Fatal_Model_Count.groupby(['Event.Id','Accident.Number']).count()
# Out:
#                                 Model  Incident.Severity
# Event.Id       Accident.Number
# 20001206X00618 FTW94FA060B          1                  1
# 20001206X01822 NYC94FA128           1                  1
# 20001206X01926 ANC94LA126           1                  1
# 20001206X02737 LAX95FA062           1                  1
# 20001207X03179 NYC95LA070           1                  1
# ...                               ...                ...
# 20221215106460 ERA23LA088           1                  1
# 20221215106463 ERA23LA090           1                  1
# 20221219106470 ERA23LA091           1                  1
# 20221219106475 WPR23LA069           1                  1
# 20221227106497 WPR23LA075           1                  1
#
# [20796 rows x 2 columns]

# %%
Fatal_Model_Count.groupby(['Event.Id','Accident.Number']).count().value_counts()
# Out:
# Model  Incident.Severity
# 1      1                    20780
# 2      2                       12
# 0      1                        4
# Name: count, dtype: int64

# %%
Fatal_Model_Count[Fatal_Model_Count.duplicated]
# Out:
#              Event.Id Accident.Number Model  Incident.Severity
# 88856  20220323104818      CEN22LA149  208B                  0

# %%
Fatal_Model_Count.drop_duplicates(inplace=True)

# %%
C_Fatal_Model_Count=Fatal_Model_Count.dropna(subset=['Model'])
C_Fatal_Model_Count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20803 entries, 5 to 90345
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Event.Id           20803 non-null  object
#  1   Accident.Number    20803 non-null  object
#  2   Model              20803 non-null  object
#  3   Incident.Severity  20803 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 812.6+ KB

# %%
Fatal_Model_Count_Series=C_Fatal_Model_Count.groupby(['Model'])\
                            ['Incident.Severity'].sum()

Fatal_Model_Count_DF=Fatal_Model_Count_Series.to_frame()

Fatal_Model_Count_DF
# Out:
#                      Incident.Severity
# Model
# 0-1A                                 0
# 0-47B                                0
# 0-58A                                0
# 0-58B                                0
# 1                                    0
# ...                                ...
# Zodiac 601 Xl                        2
# Zodiac 601Xl                         0
# Zodiac Ch601Xl                       0
# Zodiac Xl                            0
# Zuber Super Drifter                  0
#
# [3120 rows x 1 columns]

# %%
Fatal_Model_Count_DF.rename(columns={'Incident.Severity':'Fatality.Count'},\
                            inplace=True)

Fatal_Model_Count_DF.sort_values('Fatality.Count',ascending=False)
# Out:
#                      Fatality.Count
# Model
# 172                              71
# Sr22                             64
# A36                              58
# 182                              45
# Pa-28-140                        40
# ...                             ...
# D-16A                             0
# D-25                              0
# D-45 (T-34B)                      0
# D-95A                             0
# Zuber Super Drifter               0
#
# [3120 rows x 1 columns]

# %%
Total_Model_Count_DF=C_Fatal_Model_Count['Model'].value_counts().to_frame()

Total_Model_Count_DF
# Out:
#             count
# Model
# 172           768
# 152           416
# 172N          293
# 182           288
# 172S          269
# ...           ...
# Bc-D            1
# Erj 170-20      1
# Uc-64A          1
# 680-F           1
# Pa42            1
#
# [3120 rows x 1 columns]

# %%
Total_Model_Count_DF.rename(columns={'count': 'Incident.Count'}, inplace=True)

# %%
Fatal_Model_Analysis=Fatal_Model_Count_DF.join(Total_Model_Count_DF, how='inner')

Fatal_Model_Analysis
# Out:
#                      Fatality.Count  Incident.Count
# Model
# 0-1A                              0               1
# 0-47B                             0               1
# 0-58A                             0               1
# 0-58B                             0               2
# 1                                 0               2
# ...                             ...             ...
# Zodiac 601 Xl                     2               2
# Zodiac 601Xl                      0               1
# Zodiac Ch601Xl                    0               1
# Zodiac Xl                         0               1
# Zuber Super Drifter               0               1
#
# [3120 rows x 2 columns]

# %%
Fatal_Model_Analysis.sort_values(by=['Incident.Count'], ascending=False, inplace=True)

Fatal_Model_Analysis
# Out:
#                      Fatality.Count  Incident.Count
# Model
# 172                              71             768
# 152                              38             416
# 172N                             40             293
# 182                              45             288
# 172S                             24             269
# ...                             ...             ...
# Dv-1                              0               1
# Drifter Ii                        0               1
# Dream Machine                     0               1
# Dragonfly Model C                 0               1
# Zuber Super Drifter               0               1
#
# [3120 rows x 2 columns]

# %%
Fatal_Model_Analysis.head(20)
# Out:
#            Fatality.Count  Incident.Count
# Model
# 172                    71             768
# 152                    38             416
# 172N                   40             293
# 182                    45             288
# 172S                   24             269
# 180                     9             233
# Pa28                   37             232
# Sr22                   64             219
# 150                    28             218
# Pa-28-140              40             211
# 172M                   31             206
# Pa-18-150              13             199
# A36                    58             191
# 172P                   13             164
# Pa-28-161              19             137
# 140                    10             131
# 170B                    9             121
# Pa-28-180              23             117
# 7Gcbc                  20             108
# 7Ac                    14             107

# %%
#import the libraries we need to visualize this

import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %%
sns.lineplot(data= Fatal_Model_Analysis.head(10), x='Model', y='Incident.Count')
# Out:
# <Axes: xlabel='Model', ylabel='Incident.Count'>

# %%
sns.lineplot(data= Fatal_Model_Analysis.head(20), x='Model', y='Incident.Count')
# Out:
# <Axes: xlabel='Model', ylabel='Incident.Count'>

# %%
#the 10 most popular airplane models
Pop_Fatal_Model_Analysis= Fatal_Model_Analysis.head(10)

Pop_Fatal_Model_Analysis
# Out:
#            Fatality.Count  Incident.Count
# Model
# 172                    71             768
# 152                    38             416
# 172N                   40             293
# 182                    45             288
# 172S                   24             269
# 180                     9             233
# Pa28                   37             232
# Sr22                   64             219
# 150                    28             218
# Pa-28-140              40             211

# %%
Pop_Fatal_Model_Analysis.reset_index(inplace=True)

Pop_Fatal_Model_Analysis
# Out:
#        Model  Fatality.Count  Incident.Count
# 0        172              71             768
# 1        152              38             416
# 2       172N              40             293
# 3        182              45             288
# 4       172S              24             269
# 5        180               9             233
# 6       Pa28              37             232
# 7       Sr22              64             219
# 8        150              28             218
# 9  Pa-28-140              40             211

# %%
##now that all of the analysis dataframnes have been prepared
#lets turn them into visual representations

# %%
#call down all the datasets

# %%
Fatal_Model_Analysis
# Out:
#                      Fatality.Count  Incident.Count
# Model
# 172                              71             768
# 152                              38             416
# 172N                             40             293
# 182                              45             288
# 172S                             24             269
# ...                             ...             ...
# Dv-1                              0               1
# Drifter Ii                        0               1
# Dream Machine                     0               1
# Dragonfly Model C                 0               1
# Zuber Super Drifter               0               1
#
# [3120 rows x 2 columns]

# %%
Number_of_Engine_Analysis
# Out:
#                    Fatality.Count  Incident.Count
# Number.of.Engines
# 1.0                          2477           17383
# 2.0                           567            2832
# 3.0                             2              44
# 4.0                            11              52

# %%
Engine_Fatality_Analysis
# Out:
#      Engine.Type  Fatality.Count  Incident.Count
# 0  Reciprocating            2475           17091
# 1      Turbo Fan              48             698
# 2      Turbo Jet              23             140
# 3     Turbo Prop             247            1198

# %%
Jet_Engine_Analysis= Engine_Fatality_Analysis.drop(labels= [0,3], axis= 'index')

# %%
Jet_Engine_Analysis
# Out:
#   Engine.Type  Fatality.Count  Incident.Count
# 1   Turbo Fan              48             698
# 2   Turbo Jet              23             140

# %%
##make a visual representation for the number of engine analysis

# %%
Number_of_Engine_Analysis.reset_index(inplace=True)

Number_of_Engine_Analysis
# Out:
#   Number.of.Engines  Fatality.Count  Incident.Count
# 0               1.0            2477           17383
# 1               2.0             567            2832
# 2               3.0               2              44
# 3               4.0              11              52

# %%
Number_of_Engine_Analysis.to_csv(\
    './data/new_data/Number_of_Airplane_Engine_Analysis.csv')

# %%
#Engine Number Analysis

x= Number_of_Engine_Analysis['Number.of.Engines']
y1= Number_of_Engine_Analysis['Fatality.Count']
y2= Number_of_Engine_Analysis['Incident.Count']

Engine_Count_Fig, Engine_Count_Axes= plt.subplots()
Fatal_Incidents_plt=Engine_Count_Axes.bar(x,y1)
Total_Incidents_plt=Engine_Count_Axes.bar(x,y2, bottom=y1)

for fat in Fatal_Incidents_plt:
    height= fat.get_height()
    Engine_Count_Axes.annotate(f'{height}', xy=(fat.get_x() + fat.get_width() / 2,\
                            height-1), xytext=(0,3), textcoords= 'offset points',\
                               ha= 'center', va= 'bottom', color= 'blue',\
                               fontweight= 'bold')

for tot in Total_Incidents_plt:
    height= tot.get_height()
    Engine_Count_Axes.annotate(f'{height}', xy=(tot.get_x() + tot.get_width() / 2,\
                            height+800), xytext=(0,3), textcoords= 'offset points',\
                               ha= 'center', va= 'bottom', color= 'black',\
                               fontweight= 'bold')

Engine_Count_Axes.set_title(\
    'Number of Flight Incidents Compared to Number of Engines on Airplane')
Engine_Count_Axes.set_ylabel('Number of Plane Incidents')
Engine_Count_Axes.set_xlabel('Number of Engines on Plane')

Engine_Count_Axes.legend([Fatal_Incidents_plt, Total_Incidents_plt], \
                              ['Fatal Incidents', 'Total Incidents'], \
                              loc = 'upper right')

plt.savefig("./images/Number_of_Airplane_Engines_Distribution.png", dpi=150)
plt.show()

# %%
Engine_Type_Analysis
# Out:
#      Engine.Type  Fatality.Count  Incident.Count
# 0  Reciprocating            2475           17091
# 1      Turbo Fan              48             698
# 2      Turbo Jet              23             140
# 3     Turbo Prop             247            1198

# %%
Engine_Type_Analysis.to_csv(\
    './data/new_data/Type_of_Engine_Airplane_Analysis.csv')

# %%
#Engine Type Analysis

x= Engine_Type_Analysis['Engine.Type']
y1= Engine_Type_Analysis['Fatality.Count']
y2= Engine_Type_Analysis['Incident.Count']

Engine_Type_Fig, Engine_Type_Axes= plt.subplots()
Fatal_Incidents_plt=Engine_Type_Axes.bar(x,y1)
Total_Incidents_plt=Engine_Type_Axes.bar(x,y2, bottom=y1)

for fat in Fatal_Incidents_plt:
    height= fat.get_height()
    Engine_Type_Axes.annotate(f'{height}', xy=(fat.get_x() + fat.get_width() / 2,\
                            height-1), xytext=(0,3), textcoords= 'offset points',\
                               ha= 'center', va= 'bottom', color= 'blue',\
                               fontweight= 'bold')

for tot in Total_Incidents_plt:
    height= tot.get_height()
    Engine_Type_Axes.annotate(f'{height}', xy=(tot.get_x() + tot.get_width() / 2,\
                            height+800), xytext=(0,3), textcoords= 'offset points',\
                               ha= 'center', va= 'bottom', color= 'black',\
                               fontweight= 'bold')

Engine_Type_Axes.set_title(\
    'Number of Flight Incidents Compared to Type of Engines on Airplane')
Engine_Type_Axes.set_ylabel('Number of Plane Incidents')
Engine_Type_Axes.set_xlabel('Type of Engines on Plane')

Engine_Type_Axes.legend([Fatal_Incidents_plt, Total_Incidents_plt], \
                              ['Fatal Incidents', 'Total Incidents'], \
                              loc = 'upper right')

plt.savefig("./images/Type_of_Airplane_Engines_Distribution.png", dpi=150)
plt.show()

# %%
Pop_Fatal_Model_Analysis
# Out:
#        Model  Fatality.Count  Incident.Count
# 0        172              71             768
# 1        152              38             416
# 2       172N              40             293
# 3        182              45             288
# 4       172S              24             269
# 5        180               9             233
# 6       Pa28              37             232
# 7       Sr22              64             219
# 8        150              28             218
# 9  Pa-28-140              40             211

# %%
Pop_Fatal_Model_Analysis.to_csv(\
    './data/new_data/Pop_Airplane_Model_Analysis.csv')

# %%
#Airplane Model Analysis

x= Pop_Fatal_Model_Analysis['Model']
y1= Pop_Fatal_Model_Analysis['Fatality.Count']
y2= Pop_Fatal_Model_Analysis['Incident.Count']

Airplane_Model_Fig, Airplane_Model_Axes= plt.subplots()
Fatal_Incidents_plt=Airplane_Model_Axes.bar(x,y1)
Total_Incidents_plt=Airplane_Model_Axes.bar(x,y2, bottom=y1)

for fat in Fatal_Incidents_plt:
    height= fat.get_height()
    Airplane_Model_Axes.annotate(f'{height}', xy=(fat.get_x() + fat.get_width() / 2,\
                            height-1), xytext=(0,3), textcoords= 'offset points',\
                               ha= 'center', va= 'bottom', color= 'blue',\
                               fontweight= 'bold')

for tot in Total_Incidents_plt:
    height= tot.get_height()
    Airplane_Model_Axes.annotate(f'{height}', xy=(tot.get_x() + tot.get_width() / 2,\
                            height+1), xytext=(0,3), textcoords= 'offset points',\
                               ha= 'center', va= 'bottom', color= 'black',\
                               fontweight= 'bold')

Airplane_Model_Axes.set_title(\
    'Number of Flight Incidents Compared to Type of Airplane Model')
Airplane_Model_Axes.set_ylabel('Number of Plane Incidents')
Airplane_Model_Axes.set_xlabel('Type of Plane Model')

Airplane_Model_Axes.legend([Fatal_Incidents_plt, Total_Incidents_plt], \
                              ['Fatal Incidents', 'Total Incidents'], \
                              loc = 'upper right')

plt.savefig("./images/Airplane_Model_Distribution.png", dpi=150)
plt.show()

# %%
c_pro_aircraft_data.head()
# Out:
#           Event.Id Accident.Number Aircraft.Category Amateur.Built  \
# 5   20170710X52551      NYC79AA106          Airplane            No
# 7   20020909X01562      SEA82DA022          Airplane            No
# 8   20020909X01561      NYC82DA015          Airplane            No
# 12  20020917X02148      FTW82FRJ07          Airplane            No
# 13  20020917X02134      FTW82FRA14          Airplane            No
#
#                  Make   Model  Number.of.Engines    Engine.Type  \
# 5   Mcdonnell Douglas     Dc9                2.0      Turbo Fan
# 7              Cessna     140                1.0  Reciprocating
# 8              Cessna    401B                2.0  Reciprocating
# 12           Bellanca  17-30A                1.0  Reciprocating
# 13             Cessna   R172K                1.0  Reciprocating
#
#    Purpose.of.flight  Total.Fatal.Injuries  Total.Serious.Injuries  \
# 5                NaN                   NaN                     NaN
# ...

# %%
c_pro_aircraft_data['Aircraft.Name']=c_pro_aircraft_data['Make']+ ' '+ \
                                    c_pro_aircraft_data['Model']

# %%
c_pro_aircraft_data.head()
# Out:
#           Event.Id Accident.Number Aircraft.Category Amateur.Built  \
# 5   20170710X52551      NYC79AA106          Airplane            No
# 7   20020909X01562      SEA82DA022          Airplane            No
# 8   20020909X01561      NYC82DA015          Airplane            No
# 12  20020917X02148      FTW82FRJ07          Airplane            No
# 13  20020917X02134      FTW82FRA14          Airplane            No
#
#                  Make   Model  Number.of.Engines    Engine.Type  \
# 5   Mcdonnell Douglas     Dc9                2.0      Turbo Fan
# 7              Cessna     140                1.0  Reciprocating
# 8              Cessna    401B                2.0  Reciprocating
# 12           Bellanca  17-30A                1.0  Reciprocating
# 13             Cessna   R172K                1.0  Reciprocating
#
#    Purpose.of.flight  Total.Fatal.Injuries  Total.Serious.Injuries  \
# 5                NaN                   NaN                     NaN
# ...

# %%
Fatal_Airplane_Count=c_pro_aircraft_data[['Event.Id','Accident.Number',\
                                          'Aircraft.Name',\
                                          'Incident.Severity']].copy()

# %%
Fatal_Airplane_Count
# Out:
#              Event.Id Accident.Number                     Aircraft.Name  \
# 5      20170710X52551      NYC79AA106             Mcdonnell Douglas Dc9
# 7      20020909X01562      SEA82DA022                        Cessna 140
# 8      20020909X01561      NYC82DA015                       Cessna 401B
# 12     20020917X02148      FTW82FRJ07                   Bellanca 17-30A
# 13     20020917X02134      FTW82FRA14                      Cessna R172K
# ...               ...             ...                               ...
# 90328  20221213106455      WPR23LA065                        Piper Pa42
# 90332  20221215106463      ERA23LA090           Cirrus Design Corp Sr22
# 90335  20221219106475      WPR23LA069                Swearingen Sa226Tc
# 90336  20221219106470      ERA23LA091                      Cessna R172K
# 90345  20221227106497      WPR23LA075  American Champion Aircraft 8Gcbc
#
#        Incident.Severity
# 5                      0
# 7                      0
# ...

# %%
Fatal_Airplane_Count[Fatal_Airplane_Count.duplicated]
# Out:
#              Event.Id Accident.Number Aircraft.Name  Incident.Severity
# 88856  20220323104818      CEN22LA149   Cessna 208B                  0

# %%
Fatal_Airplane_Count.drop_duplicates(inplace=True)

# %%
Fatal_Airplane_Count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20807 entries, 5 to 90345
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Event.Id           20807 non-null  object
#  1   Accident.Number    20807 non-null  object
#  2   Aircraft.Name      20803 non-null  object
#  3   Incident.Severity  20807 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 812.8+ KB

# %%
Fatal_Airplane_Count_Series=Fatal_Airplane_Count.groupby(['Aircraft.Name'])\
                            ['Incident.Severity'].sum()

# %%
Fatal_Airplane_Count_DF=Fatal_Airplane_Count_Series.to_frame()

# %%
Fatal_Airplane_Count_DF
# Out:
#                                     Incident.Severity
# Aircraft.Name
# 177Mf Llc Pitts Model 12                            0
# 2021Fx3 Llc Ccx-2000                                0
# Aaa Aircraft Llc Ccx-2000                           0
# Ab Sportine Aviacija Genesis 2                      0
# Ac Mfg & Dev'T Co Ch 2000                           0
# ...                                               ...
# Zivko Aeronautics Inc Edge 540                      1
# Zlin Aviation Savage Cub-S                          0
# Zlin Savage                                         0
# Zlin Z143                                           0
# Zuber Thomas P Zuber Super Drifter                  0
#
# [3902 rows x 1 columns]

# %%
Fatal_Airplane_Count_DF.rename(columns={'Incident.Severity':'Fatality.Count'},\
                            inplace=True)

# %%
Fatal_Airplane_Count_DF.sort_values('Fatality.Count',ascending=False)
# Out:
#                                              Fatality.Count
# Aircraft.Name
# Cessna 172                                               71
# Beech A36                                                51
# Cessna 182                                               45
# Cirrus Design Corp Sr22                                  44
# Piper Pa-28-140                                          40
# ...                                                     ...
# Curtiss-Wright 12Q                                        0
# Curtiss-Wright C-46A                                      0
# Curtiss-Wright Travel Air 4000                            0
# Czech Aircraft Works Spol Sro Sportscruiser               0
# Zuber Thomas P Zuber Super Drifter                        0
#
# [3902 rows x 1 columns]

# %%
Total_Aircraft_Name_Count_DF=Fatal_Airplane_Count['Aircraft.Name'].value_counts()\
                            .to_frame()

# %%
Total_Aircraft_Name_Count_DF
# Out:
#                                       count
# Aircraft.Name
# Cessna 172                              766
# Cessna 152                              416
# Cessna 172N                             293
# Cessna 182                              288
# Cessna 172S                             268
# ...                                     ...
# Embraer Emb170                            1
# Raytheon Aircraft Company Be-400A         1
# Saab 340B                                 1
# Boeing Of Canada/Dehav Div Dhc-8-311      1
# Piper Pa42                                1
#
# [3902 rows x 1 columns]

# %%
Total_Aircraft_Name_Count_DF.rename(columns={'count': 'Incident.Count'}, inplace=True)

# %%
Fatal_Airplane_Analysis_2=Fatal_Airplane_Count_DF.join(Total_Aircraft_Name_Count_DF,\
                                                       how='inner')

Fatal_Airplane_Analysis_2
# Out:
#                                     Fatality.Count  Incident.Count
# Aircraft.Name
# 177Mf Llc Pitts Model 12                         0               1
# 2021Fx3 Llc Ccx-2000                             0               1
# Aaa Aircraft Llc Ccx-2000                        0               1
# Ab Sportine Aviacija Genesis 2                   0               1
# Ac Mfg & Dev'T Co Ch 2000                        0               1
# ...                                            ...             ...
# Zivko Aeronautics Inc Edge 540                   1               1
# Zlin Aviation Savage Cub-S                       0               1
# Zlin Savage                                      0               1
# Zlin Z143                                        0               1
# Zuber Thomas P Zuber Super Drifter               0               1
#
# [3902 rows x 2 columns]

# %%
Fatal_Airplane_Analysis_2.sort_values(by=['Incident.Count'], ascending=False,\
                                      inplace=True)

# %%
Fatal_Airplane_Analysis_2
# Out:
#                                     Fatality.Count  Incident.Count
# Aircraft.Name
# Cessna 172                                      71             766
# Cessna 152                                      38             416
# Cessna 172N                                     40             293
# Cessna 182                                      45             288
# Cessna 172S                                     23             268
# ...                                            ...             ...
# Douglas C54G-Dc                                  0               1
# Douglas Dc-10-10                                 0               1
# Douglas Dc-3                                     0               1
# Douglas Dc-3/65Ar                                0               1
# Zuber Thomas P Zuber Super Drifter               0               1
#
# [3902 rows x 2 columns]

# %%
Fatal_Airplane_Analysis_2.tail()
# Out:
#                                     Fatality.Count  Incident.Count
# Aircraft.Name
# Douglas C54G-Dc                                  0               1
# Douglas Dc-10-10                                 0               1
# Douglas Dc-3                                     0               1
# Douglas Dc-3/65Ar                                0               1
# Zuber Thomas P Zuber Super Drifter               0               1

# %%
Pop_Fatal_Airplane_Analysis_2= Fatal_Airplane_Analysis_2.head(10)

Pop_Fatal_Airplane_Analysis_2
# Out:
#                  Fatality.Count  Incident.Count
# Aircraft.Name
# Cessna 172                   71             766
# Cessna 152                   38             416
# Cessna 172N                  40             293
# Cessna 182                   45             288
# Cessna 172S                  23             268
# Cessna 180                    9             233
# Piper Pa28                   37             232
# Cessna 150                   28             218
# Piper Pa-28-140              40             211
# Cessna 172M                  31             206

# %%
Pop_Fatal_Airplane_Analysis_2.reset_index(inplace=True)

Pop_Fatal_Airplane_Analysis_2
# Out:
#      Aircraft.Name  Fatality.Count  Incident.Count
# 0       Cessna 172              71             766
# 1       Cessna 152              38             416
# 2      Cessna 172N              40             293
# 3       Cessna 182              45             288
# 4      Cessna 172S              23             268
# 5       Cessna 180               9             233
# 6       Piper Pa28              37             232
# 7       Cessna 150              28             218
# 8  Piper Pa-28-140              40             211
# 9      Cessna 172M              31             206

# %%
Pop_Fatal_Airplane_Analysis_2.to_csv(\
    './data/new_data/Airplane_Model_Analysis2.csv')

# %%
#Airplane Model Analysis

x= Pop_Fatal_Airplane_Analysis_2['Aircraft.Name']
y1= Pop_Fatal_Airplane_Analysis_2['Fatality.Count']
y2= Pop_Fatal_Airplane_Analysis_2['Incident.Count']

Airplane_Model_Fig2, Airplane_Model_Axes2= plt.subplots()
Fatal_Incidents_plt2=Airplane_Model_Axes2.bar(x,y1)
Total_Incidents_plt2=Airplane_Model_Axes2.bar(x,y2, bottom=y1)

for fat in Fatal_Incidents_plt2:
    height= fat.get_height()
    Airplane_Model_Axes2.annotate(f'{height}', xy=(fat.get_x() + fat.get_width() / 2,\
                            height-1), xytext=(0,3), textcoords= 'offset points',\
                               ha= 'center', va= 'bottom', color= 'blue',\
                               fontweight= 'bold')

for tot in Total_Incidents_plt2:
    height= tot.get_height()
    Airplane_Model_Axes2.annotate(f'{height}', xy=(tot.get_x() + tot.get_width() / 2,\
                            height+1), xytext=(0,3), textcoords= 'offset points',\
                               ha= 'center', va= 'bottom', color= 'black',\
                               fontweight= 'bold')

Airplane_Model_Axes2.set_title(\
    'Number of Flight Incidents Compared to Type of Airplane Model')
Airplane_Model_Axes2.set_ylabel('Number of Plane Incidents')
Airplane_Model_Axes2.set_xlabel('Type of Plane Model')
Airplane_Model_Axes2.set_xticklabels(Pop_Fatal_Airplane_Analysis_2['Aircraft.Name'],\
                                     rotation=-45, ha='left')

Airplane_Model_Axes2.legend([Fatal_Incidents_plt2, Total_Incidents_plt2], \
                              ['Fatal Incidents', 'Total Incidents'], \
                              loc = 'upper right')

plt.savefig("./images/Airplane_Model_Distribution2.png", dpi=150)
plt.show()
# Out:
# /var/folders/p_/7g5qyc8d5zv5nfywm65yhpkc0000gn/T/ipykernel_52760/3084868922.py:29: UserWarning: FixedFormatter should only be used together with FixedLocator
#   Airplane_Model_Axes2.set_xticklabels(Pop_Fatal_Airplane_Analysis_2['Aircraft.Name'],\

# %%
#Airplane Model Analysis

x= Pop_Fatal_Model_Analysis['Model']
y1= Pop_Fatal_Model_Analysis['Fatality.Count']
y2= Pop_Fatal_Model_Analysis['Incident.Count']

Airplane_Model_Fig, Airplane_Model_Axes= plt.subplots()
Fatal_Incidents_plt=Airplane_Model_Axes.bar(x,y1)
Total_Incidents_plt=Airplane_Model_Axes.bar(x,y2, bottom=y1)

for fat in Fatal_Incidents_plt:
    height= fat.get_height()
    Airplane_Model_Axes.annotate(f'{height}', xy=(fat.get_x() + fat.get_width() / 2,\
                            height-1), xytext=(0,3), textcoords= 'offset points',\
                               ha= 'center', va= 'bottom', color= 'blue',\
                               fontweight= 'bold')

for tot in Total_Incidents_plt:
    height= tot.get_height()
    Airplane_Model_Axes.annotate(f'{height}', xy=(tot.get_x() + tot.get_width() / 2,\
                            height+1), xytext=(0,3), textcoords= 'offset points',\
                               ha= 'center', va= 'bottom', color= 'black',\
                               fontweight= 'bold')

Airplane_Model_Axes.set_title(\
    'Number of Flight Incidents Compared to Type of Airplane Model')
Airplane_Model_Axes.set_ylabel('Number of Plane Incidents')
Airplane_Model_Axes.set_xlabel('Type of Plane Model')

Airplane_Model_Axes.legend([Fatal_Incidents_plt, Total_Incidents_plt], \
                              ['Fatal Incidents', 'Total Incidents'], \
                              loc = 'upper right')

plt.savefig("./images/Airplane_Model_Distribution.png", dpi=150)
plt.show()

# %%
# show all the displays

# %%
#Airplane Model Analysis

x= Pop_Fatal_Airplane_Analysis_2['Aircraft.Name']
y1= Pop_Fatal_Airplane_Analysis_2['Fatality.Count']
y2= Pop_Fatal_Airplane_Analysis_2['Incident.Count']

Airplane_Model_Fig2, Airplane_Model_Axes2= plt.subplots(figsize= (7,11))
Fatal_Incidents_plt2=Airplane_Model_Axes2.bar(x,y1)
Total_Incidents_plt2=Airplane_Model_Axes2.bar(x,y2, bottom=y1)

for fat in Fatal_Incidents_plt2:
    height= fat.get_height()
    Airplane_Model_Axes2.annotate(f'{height}', xy=(fat.get_x() + fat.get_width() / 2,\
                            height-1), xytext=(0,3), textcoords= 'offset points',\
                               ha= 'center', va= 'bottom', color= 'blue',\
                               fontweight= 'bold')

for tot in Total_Incidents_plt2:
    height= tot.get_height()
    Airplane_Model_Axes2.annotate(f'{height}', xy=(tot.get_x() + tot.get_width() / 2,\
                            height+1), xytext=(0,3), textcoords= 'offset points',\
                               ha= 'center', va= 'bottom', color= 'black',\
                               fontweight= 'bold')

Airplane_Model_Axes2.set_title(\
    'Number of Flight Incidents Compared to Type of Airplane Model')
Airplane_Model_Axes2.set_ylabel('Number of Plane Incidents')
Airplane_Model_Axes2.set_xlabel('Type of Plane Model')
Airplane_Model_Axes2.set_xticklabels(Pop_Fatal_Airplane_Analysis_2['Aircraft.Name'],\
                                     rotation=-45, ha='left')

Airplane_Model_Axes2.legend([Fatal_Incidents_plt2, Total_Incidents_plt2], \
                              ['Fatal Incidents', 'Total Incidents'], \
                              loc = 'upper right')

plt.savefig("./images/Airplane_Model_Distribution2.png", dpi=150)
plt.show()
# Out:
# /var/folders/p_/7g5qyc8d5zv5nfywm65yhpkc0000gn/T/ipykernel_52760/4051353280.py:29: UserWarning: FixedFormatter should only be used together with FixedLocator
#   Airplane_Model_Axes2.set_xticklabels(Pop_Fatal_Airplane_Analysis_2['Aircraft.Name'],\

# %%
#Engine Type Analysis

x= Engine_Type_Analysis['Engine.Type']
y1= Engine_Type_Analysis['Fatality.Count']
y2= Engine_Type_Analysis['Incident.Count']

Engine_Type_Fig, Engine_Type_Axes= plt.subplots()
Fatal_Incidents_plt=Engine_Type_Axes.bar(x,y1)
Total_Incidents_plt=Engine_Type_Axes.bar(x,y2, bottom=y1)

for fat in Fatal_Incidents_plt:
    height= fat.get_height()
    Engine_Type_Axes.annotate(f'{height}', xy=(fat.get_x() + fat.get_width() / 2,\
                            height-1), xytext=(0,3), textcoords= 'offset points',\
                               ha= 'center', va= 'bottom', color= 'blue',\
                               fontweight= 'bold')

for tot in Total_Incidents_plt:
    height= tot.get_height()
    Engine_Type_Axes.annotate(f'{height}', xy=(tot.get_x() + tot.get_width() / 2,\
                            height+800), xytext=(0,3), textcoords= 'offset points',\
                               ha= 'center', va= 'bottom', color= 'black',\
                               fontweight= 'bold')

Engine_Type_Axes.set_title(\
    'Number of Flight Incidents Compared to Type of Engines on Airplane')
Engine_Type_Axes.set_ylabel('Number of Plane Incidents')
Engine_Type_Axes.set_xlabel('Type of Engines on Plane')

Engine_Type_Axes.legend([Fatal_Incidents_plt, Total_Incidents_plt], \
                              ['Fatal Incidents', 'Total Incidents'], \
                              loc = 'upper right')

plt.savefig("./images/Type_of_Airplane_Engines_Distribution.png", dpi=150)
plt.show()

# %%
#Engine Number Analysis

x= Number_of_Engine_Analysis['Number.of.Engines']
y1= Number_of_Engine_Analysis['Fatality.Count']
y2= Number_of_Engine_Analysis['Incident.Count']

Engine_Count_Fig, Engine_Count_Axes= plt.subplots()
Fatal_Incidents_plt=Engine_Count_Axes.bar(x,y1)
Total_Incidents_plt=Engine_Count_Axes.bar(x,y2, bottom=y1)

for fat in Fatal_Incidents_plt:
    height= fat.get_height()
    Engine_Count_Axes.annotate(f'{height}', xy=(fat.get_x() + fat.get_width() / 2,\
                            height-1), xytext=(0,3), textcoords= 'offset points',\
                               ha= 'center', va= 'bottom', color= 'blue',\
                               fontweight= 'bold')

for tot in Total_Incidents_plt:
    height= tot.get_height()
    Engine_Count_Axes.annotate(f'{height}', xy=(tot.get_x() + tot.get_width() / 2,\
                            height+800), xytext=(0,3), textcoords= 'offset points',\
                               ha= 'center', va= 'bottom', color= 'black',\
                               fontweight= 'bold')

Engine_Count_Axes.set_title(\
    'Number of Flight Incidents Compared to Number of Engines on Airplane')
Engine_Count_Axes.set_ylabel('Number of Plane Incidents')
Engine_Count_Axes.set_xlabel('Number of Engines on Plane')

Engine_Count_Axes.legend([Fatal_Incidents_plt, Total_Incidents_plt], \
                              ['Fatal Incidents', 'Total Incidents'], \
                              loc = 'upper right')

plt.savefig("./images/Number_of_Airplane_Engines_Distribution.png", dpi=150)
plt.show()

# %%
#### Make a new dataframe for the analysis of weather vs fatality's

# %%
c_pro_aircraft_data.columns
# Out:
# Index(['Event.Id', 'Accident.Number', 'Aircraft.Category', 'Amateur.Built',
#        'Make', 'Model', 'Number.of.Engines', 'Engine.Type',
#        'Purpose.of.flight', 'Total.Fatal.Injuries', 'Total.Serious.Injuries',
#        'Total.Minor.Injuries', 'Total.Uninjured', 'Event.Date', 'Location',
#        'Country', 'Weather.Condition', 'Incident.Severity', 'Aircraft.Name'],
#       dtype='object')

# %%
c_pro_aircraft_data['Location'].head()
# Out:
# 5           BOSTON, MA
# 7          PULLMAN, WA
# 8     EAST HANOVER, NJ
# 12           HOMER, LA
# 13          HEARNE, TX
# Name: Location, dtype: object

# %%
c_pro_aircraft_data['State']= c_pro_aircraft_data['Location'].str[-2:]

# %%
c_pro_aircraft_data['State'].head()
# Out:
# 5     MA
# 7     WA
# 8     NJ
# 12    LA
# 13    TX
# Name: State, dtype: object

# %%
c_pro_aircraft_data['Event.Date']
# Out:
# 5        1979-09-17
# 7        1982-01-01
# 8        1982-01-01
# 12       1982-01-02
# 13       1982-01-02
#             ...
# 90328    2022-12-13
# 90332    2022-12-14
# 90335    2022-12-15
# 90336    2022-12-16
# 90345    2022-12-26
# Name: Event.Date, Length: 20808, dtype: object

# %%
c_pro_aircraft_data['Year']= c_pro_aircraft_data['Event.Date'].str[:4]

# %%
c_pro_aircraft_data['Year']
# Out:
# 5        1979
# 7        1982
# 8        1982
# 12       1982
# 13       1982
#          ...
# 90328    2022
# 90332    2022
# 90335    2022
# 90336    2022
# 90345    2022
# Name: Year, Length: 20808, dtype: object

# %%
c_pro_aircraft_data.head()
# Out:
#           Event.Id Accident.Number Aircraft.Category Amateur.Built  \
# 5   20170710X52551      NYC79AA106          Airplane            No
# 7   20020909X01562      SEA82DA022          Airplane            No
# 8   20020909X01561      NYC82DA015          Airplane            No
# 12  20020917X02148      FTW82FRJ07          Airplane            No
# 13  20020917X02134      FTW82FRA14          Airplane            No
#
#                  Make   Model  Number.of.Engines    Engine.Type  \
# 5   Mcdonnell Douglas     Dc9                2.0      Turbo Fan
# 7              Cessna     140                1.0  Reciprocating
# 8              Cessna    401B                2.0  Reciprocating
# 12           Bellanca  17-30A                1.0  Reciprocating
# 13             Cessna   R172K                1.0  Reciprocating
#
#    Purpose.of.flight  Total.Fatal.Injuries  ...  Total.Minor.Injuries  \
# 5                NaN                   NaN  ...                   1.0
# ...

# %%
#regions

West= ['WA','OR','CA','HI','AK','ID','NV','MT','WY','UT','CO','AZ','NM']
Midwest= ['ND','SD','NE','KS','MN','IA','MO','WI','IL','MI','IN','OH']
Northeast= ['PA','NY','NJ','CT','RI','MA','VT','NH','ME']
South= ['TX','OK','AR','LA','KY','TN','MS','AL','WV','DE','MD','DC','VA','NC','SC','GA','FL']

# %%
def where_am_i(x):
    if x in West:
        return 'West'
    elif x in Midwest:
        return 'Midwest'
    elif x in Northeast:
        return 'Northeast'
    elif x in South:
        return 'South'

# %%
#c_pro_aircraft_data['Incident.Severity']=c_pro_aircraft_data\
#['Total.Fatal.Injuries'].map(lambda x: 1 if x >= 1 else 0)

# %%
c_pro_aircraft_data['Region']= c_pro_aircraft_data['State'].apply( lambda x : where_am_i(x))

# %%
c_pro_aircraft_data['Region'].head()
# Out:
# 5     Northeast
# 7          West
# 8     Northeast
# 12        South
# 13        South
# Name: Region, dtype: object

# %%
c_pro_aircraft_data.head()
# Out:
#           Event.Id Accident.Number Aircraft.Category Amateur.Built  \
# 5   20170710X52551      NYC79AA106          Airplane            No
# 7   20020909X01562      SEA82DA022          Airplane            No
# 8   20020909X01561      NYC82DA015          Airplane            No
# 12  20020917X02148      FTW82FRJ07          Airplane            No
# 13  20020917X02134      FTW82FRA14          Airplane            No
#
#                  Make   Model  Number.of.Engines    Engine.Type  \
# 5   Mcdonnell Douglas     Dc9                2.0      Turbo Fan
# 7              Cessna     140                1.0  Reciprocating
# 8              Cessna    401B                2.0  Reciprocating
# 12           Bellanca  17-30A                1.0  Reciprocating
# 13             Cessna   R172K                1.0  Reciprocating
#
#    Purpose.of.flight  Total.Fatal.Injuries  ...  Total.Uninjured  Event.Date  \
# 5                NaN                   NaN  ...             44.0  1979-09-17
# ...

# %%
c_pro_aircraft_data[c_pro_aircraft_data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Event.Id, Accident.Number, Aircraft.Category, Amateur.Built, Make, Model, Number.of.Engines, Engine.Type, Purpose.of.flight, Total.Fatal.Injuries, Total.Serious.Injuries, Total.Minor.Injuries, Total.Uninjured, Event.Date, Location, Country, Weather.Condition, Incident.Severity, Aircraft.Name, State, Year, Region]
# Index: []
#
# [0 rows x 22 columns]

# %%
c_pro_aircraft_data['Weather.Condition'].value_counts()
# Out:
# Weather.Condition
# Vmc    18976
# Imc     1245
# Unk      160
# Name: count, dtype: int64

# %%
c_pro_aircraft_data['Region'].value_counts()
# Out:
# Region
# West         7955
# South        7112
# Midwest      3763
# Northeast    1852
# Name: count, dtype: int64

# %%
regional_weather= c_pro_aircraft_data[['Weather.Condition', \
                                                'Region', 'Year']]

# %%
regional_weather.head()
# Out:
#    Weather.Condition     Region  Year
# 5                Vmc  Northeast  1979
# 7                Vmc       West  1982
# 8                Imc  Northeast  1982
# 12               Imc      South  1982
# 13               Imc      South  1982

# %%
regional_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20808 entries, 5 to 90345
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Weather.Condition  20381 non-null  object
#  1   Region             20682 non-null  object
#  2   Year               20808 non-null  object
# dtypes: object(3)
# memory usage: 650.2+ KB

# %%
c_regional_weather= regional_weather\
[regional_weather['Weather.Condition']== 'Imc']

# %%
c_regional_weather
# Out:
#       Weather.Condition     Region  Year
# 8                   Imc  Northeast  1982
# 12                  Imc      South  1982
# 13                  Imc      South  1982
# 14                  Imc      South  1982
# 15                  Imc      South  1982
# ...                 ...        ...   ...
# 90245               Imc    Midwest  2022
# 90281               Imc    Midwest  2022
# 90286               Imc      South  2022
# 90293               Imc      South  2022
# 90302               Imc      South  2022
#
# [1245 rows x 3 columns]

# %%
regional_weather_count_series= c_regional_weather.groupby(['Region'])\
['Weather.Condition'].count()

# %%
regional_weather_count_series
# Out:
# Region
# Midwest      283
# Northeast    141
# South        478
# West         332
# Name: Weather.Condition, dtype: int64

# %%
Regional_IMC_DF=regional_weather_count_series.to_frame()
Regional_IMC_DF
# Out:
#            Weather.Condition
# Region
# Midwest                  283
# Northeast                141
# South                    478
# West                     332

# %%
Regional_IMC_DF.rename(columns={'Weather.Condition':\
    'IMC.Weather.Events'},inplace=True)

Regional_IMC_DF
# Out:
#            IMC.Weather.Events
# Region
# Midwest                   283
# Northeast                 141
# South                     478
# West                      332

# %%
Weather_Incident_Series=regional_weather['Region'].value_counts()
Weather_Incident_DF=Weather_Incident_Series.to_frame()
Weather_Incident_DF
# Out:
#            count
# Region
# West        7955
# South       7112
# Midwest     3763
# Northeast   1852

# %%
Weather_Incident_DF.rename(columns={'count':\
    'Total.Weather.Events'},inplace=True)

Weather_Incident_DF
# Out:
#            Total.Weather.Events
# Region
# West                       7955
# South                      7112
# Midwest                    3763
# Northeast                  1852

# %%
Regional_IMC_DF.reset_index(inplace=True)
Regional_IMC_DF
# Out:
#       Region  IMC.Weather.Events
# 0    Midwest                 283
# 1  Northeast                 141
# 2      South                 478
# 3       West                 332

# %%
#Regional Weather Analysis

x= Regional_IMC_DF['Region']
y= Regional_IMC_DF['IMC.Weather.Events']

IMC_Weather_Fig, IMC_Weather_Axes= plt.subplots()
IMC_Weather_plt=IMC_Weather_Axes.bar(x,y)


for event in IMC_Weather_plt:
    height= event.get_height()
    IMC_Weather_Axes.annotate(f'{height}', xy=(event.get_x() + event.get_width() / 2,\
                            height-50), xytext=(0,3), textcoords= 'offset points',\
                               ha= 'center', va= 'bottom', color= 'white',\
                               fontweight= 'bold')

IMC_Weather_Axes.set_title(\
    'Number of IMC Weather Incidents for Each Region in America')
IMC_Weather_Axes.set_ylabel('Number of IMC Incidents')
IMC_Weather_Axes.set_xlabel('Regions of America')

IMC_Weather_Axes.legend([IMC_Weather_plt], \
                              ['IMC Incidents'], \
                              loc = 'upper left')

plt.savefig("./images/Regional_Weather_Analysis_Distribution.png", dpi=150)
plt.show()

# %%
Jet_Engine_Analysis
# Out:
#   Engine.Type  Fatality.Count  Incident.Count
# 1   Turbo Fan              48             698
# 2   Turbo Jet              23             140

# %%
#Jet Engine Type Analysis

x= Jet_Engine_Analysis['Engine.Type']
y1= Jet_Engine_Analysis['Fatality.Count']
y2= Jet_Engine_Analysis['Incident.Count']

Jet_Engine_Fig, Jet_Engine_Axes= plt.subplots()
Fatal_Jet_Incidents_plt=Jet_Engine_Axes.bar(x,y1)
Total_Jet_Incidents_plt=Jet_Engine_Axes.bar(x,y2, bottom=y1)

for FEng in Fatal_Jet_Incidents_plt:
    height= FEng.get_height()
    Jet_Engine_Axes.annotate(f'{height}', xy=(FEng.get_x() + FEng.get_width() / 2,\
                            height-1), xytext=(0,3), textcoords= 'offset points',\
                               ha= 'center', va= 'bottom', color= 'White',\
                               fontweight= 'bold')

for TEng in Total_Jet_Incidents_plt:
    height= TEng.get_height()
    Jet_Engine_Axes.annotate(f'{height}', xy=(TEng.get_x() + TEng.get_width() / 2,\
                            height-20), xytext=(0,3), textcoords= 'offset points',\
                               ha= 'center', va= 'bottom', color= 'black',\
                               fontweight= 'bold')

Jet_Engine_Axes.set_title(\
    'Type of Jet Engine VS Number of Incidents')
Jet_Engine_Axes.set_ylabel('Number of Plane Incidents')
Jet_Engine_Axes.set_xlabel('Number of Engines on Plane')

Jet_Engine_Axes.legend([Fatal_Jet_Incidents_plt, Total_Jet_Incidents_plt], \
                              ['Fatal Incidents', 'Total Incidents'], \
                              loc = 'upper right')

plt.savefig("./images/Jet_Engine_Incident_Distrobution.png", dpi=150)
plt.show()

# %%
#could potentially do an analysis of what size jets tend to get more fatal
#accidents, like small = under 10 occupents, med = 11 to 35 occupants, large = 36 and 
#over occupents

# %%
#we could calculate this by adding up the 4 different injury type 
#columns to get the total number of people on the plane

# %%
#maybe something with purpose of flight

# %%
c_pro_aircraft_data.head()
# Out:
#           Event.Id Accident.Number Aircraft.Category Amateur.Built  \
# 5   20170710X52551      NYC79AA106          Airplane            No
# 7   20020909X01562      SEA82DA022          Airplane            No
# 8   20020909X01561      NYC82DA015          Airplane            No
# 12  20020917X02148      FTW82FRJ07          Airplane            No
# 13  20020917X02134      FTW82FRA14          Airplane            No
#
#                  Make   Model  Number.of.Engines    Engine.Type  \
# 5   Mcdonnell Douglas     Dc9                2.0      Turbo Fan
# 7              Cessna     140                1.0  Reciprocating
# 8              Cessna    401B                2.0  Reciprocating
# 12           Bellanca  17-30A                1.0  Reciprocating
# 13             Cessna   R172K                1.0  Reciprocating
#
#    Purpose.of.flight  Total.Fatal.Injuries  ...  Total.Uninjured  Event.Date  \
# 5                NaN                   NaN  ...             44.0  1979-09-17
# ...

# %%
c_pro_aircraft_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20808 entries, 5 to 90345
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                20808 non-null  object
#  1   Accident.Number         20808 non-null  object
#  2   Aircraft.Category       20808 non-null  object
#  3   Amateur.Built           20808 non-null  object
#  4   Make                    20808 non-null  object
#  5   Model                   20804 non-null  object
#  6   Number.of.Engines       20324 non-null  float64
#  7   Engine.Type             19158 non-null  object
#  8   Purpose.of.flight       19583 non-null  object
#  9   Total.Fatal.Injuries    18535 non-null  float64
#  10  Total.Serious.Injuries  18527 non-null  float64
#  11  Total.Minor.Injuries    18504 non-null  float64
#  12  Total.Uninjured         20562 non-null  float64
#  13  Event.Date              20808 non-null  object
# ...

# %%
c_pro_aircraft_data['Number.of.Passengers']=c_pro_aircraft_data['Total.Fatal.Injuries']\
                                            +c_pro_aircraft_data['Total.Serious.Injuries']\
                                            +c_pro_aircraft_data['Total.Minor.Injuries']\
                                            +c_pro_aircraft_data['Total.Uninjured']

# %%
c_pro_aircraft_data['Number.of.Passengers'].head()
# Out:
# 5     NaN
# 7     2.0
# 8     2.0
# 12    1.0
# 13    1.0
# Name: Number.of.Passengers, dtype: float64

# %%
Aircraft_size= c_pro_aircraft_data[['Total.Fatal.Injuries', 'Total.Serious.Injuries', 'Total.Minor.Injuries',\
                'Total.Uninjured', 'Year', 'Incident.Severity']]

# %%
C_Aircraft_Size= Aircraft_size.dropna(subset=['Total.Fatal.Injuries', 'Total.Serious.Injuries',\
                                              'Total.Minor.Injuries', 'Total.Uninjured'])

# %%
C_Aircraft_Size['Number.of.Passengers']=Aircraft_size['Total.Fatal.Injuries']\
                                            +Aircraft_size['Total.Serious.Injuries']\
                                            +Aircraft_size['Total.Minor.Injuries']\
                                            +Aircraft_size['Total.Uninjured']

# %%
C_Aircraft_Size['Number.of.Passengers'].head()
# Out:
# 7     2.0
# 8     2.0
# 12    1.0
# 13    1.0
# 14    1.0
# Name: Number.of.Passengers, dtype: float64

# %%
C_Aircraft_Size['Number.of.Passengers'].hist()
# Out:
# <Axes: >

# %%
C_Aircraft_Size['Number.of.Passengers'].describe()
# Out:
# count    18362.000000
# mean         5.372127
# std         24.660941
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max        576.000000
# Name: Number.of.Passengers, dtype: float64

# %%
def size_selector(x):
    if x <= 10:
        return 'Personal'
    elif 11 <= x <= 50:
        return 'Small'
    elif 51 <= x <= 100:
        return 'Medium'
    elif 101 <= x <= 200:
        return 'Large'
    else:
        return 'Jumbo'

# %%
C_Aircraft_Size['Aircraft.Size']= C_Aircraft_Size['Number.of.Passengers'].apply( lambda x : size_selector(x))

# %%
C_Aircraft_Size['Aircraft.Size'].head()
# Out:
# 7     Personal
# 8     Personal
# 12    Personal
# 13    Personal
# 14    Personal
# Name: Aircraft.Size, dtype: object

# %%
Aircraft_Size_Series= C_Aircraft_Size.groupby(['Aircraft.Size'])\
['Incident.Severity'].count()

# %%
Aircraft_Size_DF=Aircraft_Size_Series.to_frame()
Aircraft_Size_DF.reset_index(inplace=True)
Aircraft_Size_DF.rename(columns={'Incident.Severity':\
    'Fatal.Events'},inplace=True)
Aircraft_Size_DF
# Out:
#   Aircraft.Size  Fatal.Events
# 0         Jumbo            67
# 1         Large           242
# 2        Medium           108
# 3      Personal         17806
# 4         Small           139

# %%
Aircraft_Size_Series_2= C_Aircraft_Size.groupby(['Aircraft.Size', 'Year'])\
['Incident.Severity'].sum()

# %%
Aircraft_Size_DF_2=Aircraft_Size_Series_2.to_frame()
Aircraft_Size_DF_2.reset_index(inplace=True)
Aircraft_Size_DF_2.rename(columns={'Incident.Severity':\
    'Fatal.Events'},inplace=True)
Aircraft_Size_DF_2
# Out:
#    Aircraft.Size  Year  Fatal.Events
# 0          Jumbo  1982             1
# 1          Jumbo  2005             0
# 2          Jumbo  2007             0
# 3          Jumbo  2008             0
# 4          Jumbo  2009             0
# ..           ...   ...           ...
# 91         Small  2018             0
# 92         Small  2019             5
# 93         Small  2020             0
# 94         Small  2021             0
# 95         Small  2022             0
#
# [96 rows x 3 columns]

# %%
#Jet Size Analysis

x= Aircraft_Size_DF_2['Aircraft.Size']
y= Aircraft_Size_DF_2['Fatal.Events']

Aircraft_Size_Fig, Aircraft_Size_Axes= plt.subplots()
Aircraft_Size_plt=Aircraft_Size_Axes.bar(x,y)

Aircraft_Size_Axes.set_title(\
    'Number of Fatal Events for Each Jet Size')
Aircraft_Size_Axes.set_ylabel('Number of Fatal Incidents')
Aircraft_Size_Axes.set_xlabel('Size of Jet')
Aircraft_Size_Axes.set_ylim([0,100])

Aircraft_Size_Axes.legend([Aircraft_Size_plt], \
                              ['IMC Incidents'], \
                              loc = 'upper left')

plt.savefig("./images/Aircraft_Size_Analysis_Distribution.png", dpi=150)
plt.show()

# %%
#Jet Size Analysis

x= Aircraft_Size_DF['Aircraft.Size']
y= Aircraft_Size_DF['Fatal.Events']

Aircraft_Size_Fig, Aircraft_Size_Axes= plt.subplots()
Aircraft_Size_plt=Aircraft_Size_Axes.bar(x,y)


for size in Aircraft_Size_plt:
    height= size.get_height()
    Aircraft_Size_Axes.annotate(f'{height}', xy=(size.get_x() + size.get_width() / 2,\
                            height-50), xytext=(0,3), textcoords= 'offset points',\
                               ha= 'center', va= 'bottom', color= 'black',\
                               fontweight= 'bold')

Aircraft_Size_Axes.set_title(\
    'Number of Fatal Events for Each Jet Size')
Aircraft_Size_Axes.set_ylabel('Number of Fatal Incidents')
Aircraft_Size_Axes.set_xlabel('Size of Jet')
Aircraft_Size_Axes.set_ylim([0,500])

Aircraft_Size_Axes.legend([Aircraft_Size_plt], \
                              ['Fatal Incidents'], \
                              loc = 'upper left')

plt.savefig("./images/Aircraft_Size_Analysis_Distribution_2.png", dpi=150)
plt.show()
