# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
len('jmftiognroengkjlrekjngrkolengonreoingmoringreoiqngoireqmgnoivnjfkdbnvijfd5')
# Out:
# 74

# %%
# Your code here - remember to use markdown cells for comments as well!

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Next I will import the data stored on the .CSV file and save it to a dataframe 

Aviation_Data= pd.read_csv('data/Aviation_Data.csv', low_memory=False)

# %%
#Now I will start exploring the data

Aviation_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90348 entries, 0 to 90347
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      90348 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Latitude                34382 non-null  object
#  7   Longitude               34373 non-null  object
#  8   Airport.Code            50132 non-null  object
#  9   Airport.Name            52704 non-null  object
#  10  Injury.Severity         87889 non-null  object
#  11  Aircraft.damage         85695 non-null  object
#  12  Aircraft.Category       32287 non-null  object
#  13  Registration.Number     87507 non-null  object
# ...

# %%
#taking a look at a sample of the data

Aviation_Data.head()
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
#
#           Location        Country   Latitude   Longitude Airport.Code  \
# 0  MOOSE CREEK, ID  United States        NaN         NaN          NaN
# 1   BRIDGEPORT, CA  United States        NaN         NaN          NaN
# 2    Saltville, VA  United States  36.922223  -81.878056          NaN
# 3       EUREKA, CA  United States        NaN         NaN          NaN
# 4       Canton, OH  United States        NaN         NaN          NaN
#
#   Airport.Name  ... Purpose.of.flight Air.carrier Total.Fatal.Injuries  \
# 0          NaN  ...          Personal         NaN                  2.0
# ...

# %%
Aviation_Data['Total.Fatal.Injuries'].value_counts()
# Out:
# Total.Fatal.Injuries
# 0.0      59675
# 1.0       8883
# 2.0       5173
# 3.0       1589
# 4.0       1103
#          ...
# 156.0        1
# 68.0         1
# 31.0         1
# 115.0        1
# 176.0        1
# Name: count, Length: 125, dtype: int64

# %%
#see if there are re-occuring event id's
Aviation_Data['Event.Id'].value_counts()
# Out:
# Event.Id
# 20001212X19172    3
# 20001214X45071    3
# 20220730105623    2
# 20051213X01965    2
# 20001212X16765    2
#                  ..
# 20001211X14216    1
# 20001211X14239    1
# 20001211X14207    1
# 20001211X14204    1
# 20221230106513    1
# Name: count, Length: 87951, dtype: int64

# %%
Aviation_Data['Number.of.Engines'].value_counts()
# Out:
# Number.of.Engines
# 1.0    69582
# 2.0    11079
# 0.0     1226
# 3.0      483
# 4.0      431
# 8.0        3
# 6.0        1
# Name: count, dtype: int64

# %%
Aviation_Data['Engine.Type'].value_counts()
# Out:
# Engine.Type
# Reciprocating      69530
# Turbo Shaft         3609
# Turbo Prop          3391
# Turbo Fan           2481
# Unknown             2051
# Turbo Jet            703
# Geared Turbofan       12
# Electric              10
# LR                     2
# NONE                   2
# Hybrid Rocket          1
# UNK                    1
# Name: count, dtype: int64

# %%
Aviation_Data['Investigation.Type'].value_counts()
# Out:
# Investigation.Type
# Accident      85015
# Incident       3874
# 25-09-2020      702
# 26-09-2020       60
# 02-02-2021       39
#               ...
# 13-09-2021        1
# 04-08-2021        1
# 05-08-2022        1
# 03-11-2020        1
# 06-01-2021        1
# Name: count, Length: 71, dtype: int64

# %%
Aviation_Data['Accident.Number'].value_counts()
# Out:
# Accident.Number
# CEN22LA149    2
# WPR23LA041    2
# WPR23LA045    2
# DCA22WA214    2
# DCA22WA089    2
#              ..
# LAX92FA065    1
# ANC92T#A12    1
# MIA92LA049    1
# NYC92LA048    1
# ERA23LA097    1
# Name: count, Length: 88863, dtype: int64

# %%
Aviation_Data['Injury.Severity'].value_counts()
# Out:
# Injury.Severity
# Non-Fatal     67357
# Fatal(1)       6167
# Fatal          5262
# Fatal(2)       3711
# Incident       2219
#               ...
# Fatal(270)        1
# Fatal(60)         1
# Fatal(43)         1
# Fatal(143)        1
# Fatal(230)        1
# Name: count, Length: 109, dtype: int64

# %%
Aviation_Data['Aircraft.damage'].value_counts()
# Out:
# Aircraft.damage
# Substantial    64148
# Destroyed      18623
# Minor           2805
# Unknown          119
# Name: count, dtype: int64

# %%
Aviation_Data['Aircraft.Category'].value_counts()
# Out:
# Aircraft.Category
# Airplane             27617
# Helicopter            3440
# Glider                 508
# Balloon                231
# Gyrocraft              173
# Weight-Shift           161
# Powered Parachute       91
# Ultralight              30
# Unknown                 14
# WSFT                     9
# Powered-Lift             5
# Blimp                    4
# UNK                      2
# Rocket                   1
# ULTR                     1
# Name: count, dtype: int64

# %%
Aviation_Data['Registration.Number'].value_counts()
# Out:
# Registration.Number
# NONE      344
# UNREG     126
# UNK        13
# USAF        9
# N20752      8
#          ...
# N93478      1
# N519UA      1
# N8840W      1
# N21040      1
# N9026P      1
# Name: count, Length: 79104, dtype: int64

# %%
Aviation_Data['Make'].value_counts()
# Out:
# Make
# Cessna             22227
# Piper              12029
# CESSNA              4922
# Beech               4330
# PIPER               2841
#                    ...
# Leonard Walters        1
# Maule Air Inc.         1
# Motley Vans            1
# Perlick                1
# ROYSE RALPH L          1
# Name: count, Length: 8237, dtype: int64

# %%
Aviation_Data['Model'].value_counts()
# Out:
# Model
# 152              2367
# 172              1756
# 172N             1164
# PA-28-140         932
# 150               829
#                  ...
# GC-1-A              1
# 737-3S3             1
# MBB-BK117-B2        1
# GLASSAIR GL25       1
# M-8 EAGLE           1
# Name: count, Length: 12318, dtype: int64

# %%
Aviation_Data['Amateur.Built'].value_counts()
# Out:
# Amateur.Built
# No     80312
# Yes     8475
# Name: count, dtype: int64

# %%
Aviation_Data['FAR.Description'].value_counts()
# Out:
# FAR.Description
# 091                               18221
# Part 91: General Aviation          6486
# NUSN                               1584
# NUSC                               1013
# 137                                1010
# 135                                 746
# 121                                 679
# Part 137: Agricultural              437
# UNK                                 371
# Part 135: Air Taxi & Commuter       298
# PUBU                                253
# 129                                 246
# Part 121: Air Carrier               165
# 133                                 107
# Part 129: Foreign                   100
# Non-U.S., Non-Commercial             97
# Non-U.S., Commercial                 93
# Part 133: Rotorcraft Ext. Load       32
# Unknown                              22
# Public Use                           19
# 091K                                 14
# ARMF                                  8
# Part 125: 20+ Pax,6000+ lbs           5
# ...

# %%
Aviation_Data['Schedule'].value_counts()
# Out:
# Schedule
# NSCH    4474
# UNK     4099
# SCHD    4009
# Name: count, dtype: int64

# %%
Aviation_Data['Purpose.of.flight'].value_counts()
# Out:
# Purpose.of.flight
# Personal                     49448
# Instructional                10601
# Unknown                       6802
# Aerial Application            4712
# Business                      4018
# Positioning                   1646
# Other Work Use                1264
# Ferry                          812
# Aerial Observation             794
# Public Aircraft                720
# Executive/corporate            553
# Flight Test                    405
# Skydiving                      182
# External Load                  123
# Public Aircraft - Federal      105
# Banner Tow                     101
# Air Race show                   99
# Public Aircraft - Local         74
# Public Aircraft - State         64
# Air Race/show                   59
# Glider Tow                      53
# Firefighting                    40
# Air Drop                        11
# ASHO                             6
# PUBS                             4
# PUBL                             1
# ...

# %%
Aviation_Data['Air.carrier'].value_counts()
# Out:
# Air.carrier
# Pilot                        258
# American Airlines             90
# United Airlines               89
# Delta Air Lines               53
# SOUTHWEST AIRLINES CO         42
#                             ...
# WOODY CONTRACTING INC          1
# Rod Aviation LLC               1
# Paul D Franzon                 1
# TRAINING SERVICES INC DBA      1
# MC CESSNA 210N LLC             1
# Name: count, Length: 13590, dtype: int64

# %%
Aviation_Data['Total.Fatal.Injuries'].value_counts()
# Out:
# Total.Fatal.Injuries
# 0.0      59675
# 1.0       8883
# 2.0       5173
# 3.0       1589
# 4.0       1103
#          ...
# 156.0        1
# 68.0         1
# 31.0         1
# 115.0        1
# 176.0        1
# Name: count, Length: 125, dtype: int64

# %%
Aviation_Data['Total.Serious.Injuries'].value_counts()
# Out:
# Total.Serious.Injuries
# 0.0      63289
# 1.0       9125
# 2.0       2815
# 3.0        629
# 4.0        258
# 5.0         78
# 6.0         41
# 7.0         27
# 9.0         16
# 10.0        13
# 8.0         13
# 13.0         9
# 11.0         6
# 26.0         5
# 14.0         5
# 12.0         5
# 20.0         3
# 25.0         3
# 28.0         3
# 21.0         2
# 59.0         2
# 50.0         2
# 17.0         2
# 47.0         2
# 137.0        1
# 19.0         1
# 161.0        1
# 27.0         1
# 35.0         1
# 67.0         1
# 33.0         1
# 88.0         1
# 125.0        1
# 53.0         1
# 34.0         1
# 41.0         1
# 18.0         1
# 63.0         1
# 55.0         1
# 23.0         1
# 43.0         1
# 39.0         1
# 45.0         1
# 44.0         1
# 16.0         1
# 60.0         1
# 106.0        1
# 81.0         1
# 15.0         1
# 22.0         1
# Name: count, dtype: int64

# %%
Aviation_Data['Total.Minor.Injuries'].value_counts()
# Out:
# Total.Minor.Injuries
# 0.0      61454
# 1.0      10320
# 2.0       3576
# 3.0        784
# 4.0        372
# 5.0        129
# 6.0         67
# 7.0         59
# 9.0         22
# 8.0         20
# 13.0        14
# 10.0        11
# 12.0        11
# 14.0        10
# 11.0         9
# 17.0         8
# 19.0         6
# 18.0         6
# 24.0         5
# 22.0         5
# 25.0         4
# 16.0         4
# 15.0         4
# 33.0         4
# 20.0         3
# 21.0         3
# 26.0         3
# 23.0         3
# 32.0         3
# 27.0         3
# 50.0         2
# 30.0         2
# 36.0         2
# 31.0         2
# 28.0         2
# 42.0         2
# 38.0         2
# 57.0         1
# 65.0         1
# 84.0         1
# 43.0         1
# 35.0         1
# 380.0        1
# 47.0         1
# 68.0         1
# 200.0        1
# 71.0         1
# 58.0         1
# 171.0        1
# 39.0         1
# 96.0         1
# 29.0         1
# 69.0         1
# 62.0         1
# 45.0         1
# 125.0        1
# 40.0         1
# ...

# %%
Aviation_Data['Total.Uninjured'].value_counts()
# Out:
# Total.Uninjured
# 0.0      29879
# 1.0      25101
# 2.0      15988
# 3.0       4313
# 4.0       2662
#          ...
# 558.0        1
# 412.0        1
# 338.0        1
# 401.0        1
# 455.0        1
# Name: count, Length: 379, dtype: int64

# %%
Aviation_Data['Weather.Condition'].value_counts()
# Out:
# Weather.Condition
# VMC    77303
# IMC     5976
# UNK      856
# Unk      262
# Name: count, dtype: int64

# %%
Aviation_Data['Broad.phase.of.flight'].value_counts()
# Out:
# Broad.phase.of.flight
# Landing        15428
# Takeoff        12493
# Cruise         10269
# Maneuvering     8144
# Approach        6546
# Climb           2034
# Taxi            1958
# Descent         1887
# Go-around       1353
# Standing         945
# Unknown          548
# Other            119
# Name: count, dtype: int64

# %%
Aviation_Data['Report.Status'].value_counts()
# Out:
# Report.Status
# Probable Cause                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        61754
# ...

# %%
Aviation_Data['Publication.Date']
# Out:
# 0               NaN
# 1        19-09-1996
# 2        26-02-2007
# 3        12-09-2000
# 4        16-04-1980
#             ...
# 90343    29-12-2022
# 90344           NaN
# 90345    27-12-2022
# 90346           NaN
# 90347    30-12-2022
# Name: Publication.Date, Length: 90348, dtype: object

# %%
Aviation_Data['Event.Date']
# Out:
# 0        1948-10-24
# 1        1962-07-19
# 2        1974-08-30
# 3        1977-06-19
# 4        1979-08-02
#             ...
# 90343    2022-12-26
# 90344    2022-12-26
# 90345    2022-12-26
# 90346    2022-12-26
# 90347    2022-12-29
# Name: Event.Date, Length: 90348, dtype: object

# %%
##create a new dataframe from the columns that you want to keep

# %%
#see what columns you have currently

# %%
Aviation_Data.columns
# Out:
# Index(['Event.Id', 'Investigation.Type', 'Accident.Number', 'Event.Date',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Airport.Code',
#        'Airport.Name', 'Injury.Severity', 'Aircraft.damage',
#        'Aircraft.Category', 'Registration.Number', 'Make', 'Model',
#        'Amateur.Built', 'Number.of.Engines', 'Engine.Type', 'FAR.Description',
#        'Schedule', 'Purpose.of.flight', 'Air.carrier', 'Total.Fatal.Injuries',
#        'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured',
#        'Weather.Condition', 'Broad.phase.of.flight', 'Report.Status',
#        'Publication.Date'],
#       dtype='object')

# %%
Aviation_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90348 entries, 0 to 90347
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      90348 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Latitude                34382 non-null  object
#  7   Longitude               34373 non-null  object
#  8   Airport.Code            50132 non-null  object
#  9   Airport.Name            52704 non-null  object
#  10  Injury.Severity         87889 non-null  object
#  11  Aircraft.damage         85695 non-null  object
#  12  Aircraft.Category       32287 non-null  object
#  13  Registration.Number     87507 non-null  object
# ...

# %%
stripped_data=Aviation_Data[['Event.Id','Accident.Number','Aircraft.Category',
                             'Make','Model','Number.of.Engines','Engine.Type',
                             'Purpose.of.flight', 'Total.Fatal.Injuries',
                             'Total.Serious.Injuries', 'Total.Minor.Injuries',
                                 'Total.Uninjured']].copy()

# %%
stripped_data.head()
# Out:
#          Event.Id Accident.Number Aircraft.Category      Make     Model  \
# 0  20001218X45444      SEA87LA080               NaN   Stinson     108-3
# 1  20001218X45447      LAX94LA336               NaN     Piper  PA24-180
# 2  20061025X01555      NYC07LA005               NaN    Cessna      172M
# 3  20001218X45448      LAX96LA321               NaN  Rockwell       112
# 4  20041105X01764      CHI79FA064               NaN    Cessna       501
#
#    Number.of.Engines    Engine.Type Purpose.of.flight  Total.Fatal.Injuries  \
# 0                1.0  Reciprocating          Personal                   2.0
# 1                1.0  Reciprocating          Personal                   4.0
# 2                1.0  Reciprocating          Personal                   3.0
# 3                1.0  Reciprocating          Personal                   2.0
# 4                NaN            NaN          Personal                   1.0
#
#    Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured
# ...

# %%
stripped_data['Make']= stripped_data['Make'].str.title()

# %%
stripped_data['Model']= stripped_data['Model'].str.title()

# %%
stripped_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90348 entries, 0 to 90347
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Accident.Number         88889 non-null  object
#  2   Aircraft.Category       32287 non-null  object
#  3   Make                    88826 non-null  object
#  4   Model                   88797 non-null  object
#  5   Number.of.Engines       82805 non-null  float64
#  6   Engine.Type             81793 non-null  object
#  7   Purpose.of.flight       82697 non-null  object
#  8   Total.Fatal.Injuries    77488 non-null  float64
#  9   Total.Serious.Injuries  76379 non-null  float64
#  10  Total.Minor.Injuries    76956 non-null  float64
#  11  Total.Uninjured         82977 non-null  float64
# dtypes: float64(5), object(7)
# memory usage: 8.3+ MB

# %%
##clean the data

# %%
#check for duplicates in the data and remove the duplicates and copy this data to a new dataset

# %%
stripped_data.duplicated().value_counts()
# Out:
# False    88888
# True      1460
# Name: count, dtype: int64

# %%
#Lets take a look at the duplicate data to see if we can learn anything about it

# %%
stripped_data[stripped_data.duplicated]
# Out:
#       Event.Id Accident.Number Aircraft.Category Make Model  \
# 64050      NaN             NaN               NaN  NaN   NaN
# 64052      NaN             NaN               NaN  NaN   NaN
# 64388      NaN             NaN               NaN  NaN   NaN
# 64541      NaN             NaN               NaN  NaN   NaN
# 64552      NaN             NaN               NaN  NaN   NaN
# ...        ...             ...               ...  ...   ...
# 90004      NaN             NaN               NaN  NaN   NaN
# 90010      NaN             NaN               NaN  NaN   NaN
# 90031      NaN             NaN               NaN  NaN   NaN
# 90090      NaN             NaN               NaN  NaN   NaN
# 90097      NaN             NaN               NaN  NaN   NaN
#
#        Number.of.Engines Engine.Type Purpose.of.flight  Total.Fatal.Injuries  \
# 64050                NaN         NaN               NaN                   NaN
# 64052                NaN         NaN               NaN                   NaN
# ...

# %%
#there are 1,460 duplicate values in the dataframe.
#if these were actual duplicated values instead of missing values (NAN)
#this could cause a bias in any analysis we use. This data will not 
#have any positive contibution to any analysis we do so we will get rid
#of the duplicates and store the cleaned data in a new Dataframe

# %%
#strip the duplicate lines from the data, and store it in a new dataframe

# %%
data_no_dupes=stripped_data.drop_duplicates()

# %%
#confirm the duped data has been dropped

# %%
data_no_dupes.shape #confirmed the dupe data has been dropped
# Out:
# (88888, 12)

# %%
##break this dataset up into three different data sets for analysis

# %%
data_no_dupes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 88888 entries, 0 to 90347
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88887 non-null  object
#  1   Accident.Number         88887 non-null  object
#  2   Aircraft.Category       32285 non-null  object
#  3   Make                    88824 non-null  object
#  4   Model                   88795 non-null  object
#  5   Number.of.Engines       82804 non-null  float64
#  6   Engine.Type             81793 non-null  object
#  7   Purpose.of.flight       82696 non-null  object
#  8   Total.Fatal.Injuries    77486 non-null  float64
#  9   Total.Serious.Injuries  76377 non-null  float64
#  10  Total.Minor.Injuries    76954 non-null  float64
#  11  Total.Uninjured         82975 non-null  float64
# dtypes: float64(5), object(7)
# memory usage: 8.8+ MB

# %%
#this dataset will be for Engine type analysis to see if the engine 
#type has any effect on the safety of the planes

# %%
data_no_dupes.head()
# Out:
#          Event.Id Accident.Number Aircraft.Category      Make     Model  \
# 0  20001218X45444      SEA87LA080               NaN   Stinson     108-3
# 1  20001218X45447      LAX94LA336               NaN     Piper  Pa24-180
# 2  20061025X01555      NYC07LA005               NaN    Cessna      172M
# 3  20001218X45448      LAX96LA321               NaN  Rockwell       112
# 4  20041105X01764      CHI79FA064               NaN    Cessna       501
#
#    Number.of.Engines    Engine.Type Purpose.of.flight  Total.Fatal.Injuries  \
# 0                1.0  Reciprocating          Personal                   2.0
# 1                1.0  Reciprocating          Personal                   4.0
# 2                1.0  Reciprocating          Personal                   3.0
# 3                1.0  Reciprocating          Personal                   2.0
# 4                NaN            NaN          Personal                   1.0
#
#    Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured
# ...

# %%
type(data_no_dupes['Total.Fatal.Injuries'][1])
# Out:
# numpy.float64

# %%
data_no_dupes['Total.Fatal.Injuries'].value_counts()
# Out:
# Total.Fatal.Injuries
# 0.0      59673
# 1.0       8883
# 2.0       5173
# 3.0       1589
# 4.0       1103
#          ...
# 156.0        1
# 68.0         1
# 31.0         1
# 115.0        1
# 176.0        1
# Name: count, Length: 125, dtype: int64

# %%
data_no_dupes[data_no_dupes['Total.Fatal.Injuries'].isna()]
# Out:
#              Event.Id Accident.Number Aircraft.Category  \
# 5      20170710X52551      NYC79AA106          Airplane
# 89     20020917X02486      NYC82DA022               NaN
# 260    20020917X02495      NYC82DA033          Airplane
# 351    20020917X02151      FTW82IA062          Airplane
# 728    20020917X02383      MIA82DA098               NaN
# ...               ...             ...               ...
# 63905  20080214X00193      CHI08CA056          Airplane
# 63910  20080129X00122      CHI08CA057          Airplane
# 63911  20080125X00106      SEA08CA056          Airplane
# 63912  20080206X00141      CHI08WA075               NaN
# 64030             NaN             NaN               NaN
#
#                                  Make      Model  Number.of.Engines  \
# 5                   Mcdonnell Douglas        Dc9                2.0
# 89                             Cessna        310                2.0
# 260                          Bellanca      7Kcab                1.0
# ...

# %%
#after reviewing the columns with NAN in the injury columns we can tell that 
#just because the Total Fatal Injuries column may be missing data doesn't mean
#column is totaly useless. In fact in can point to their being non fatal or
#no injuries in the incident. Being that this is the case, we will only get rid of all
#the columns that have NAN across all of the injury counted rows.

#make a dataset that gets rid of all columns that have NAN
#across all injuries columns

# %%
cleaned_injury_data=data_no_dupes.dropna(subset=['Total.Fatal.Injuries',
                                                 'Total.Serious.Injuries','Total.Uninjured'],
                                         how='all').copy()

# %%
cleaned_injury_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87158 entries, 0 to 90347
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                87158 non-null  object
#  1   Accident.Number         87158 non-null  object
#  2   Aircraft.Category       31724 non-null  object
#  3   Make                    87099 non-null  object
#  4   Model                   87071 non-null  object
#  5   Number.of.Engines       81305 non-null  float64
#  6   Engine.Type             80266 non-null  object
#  7   Purpose.of.flight       81150 non-null  object
#  8   Total.Fatal.Injuries    77486 non-null  float64
#  9   Total.Serious.Injuries  76377 non-null  float64
#  10  Total.Minor.Injuries    75448 non-null  float64
#  11  Total.Uninjured         82975 non-null  float64
# dtypes: float64(5), object(7)
# memory usage: 8.6+ MB

# %%
#now that we have stripped away all of the rows that have no actuall values
#across all of the rows, we can infer that if the value in the total fatal 
#injury column is less than 1 or equal to NAN then there probably no injuries
#or only injuries that weren't fatal in the incident.

# %%
#lets check out the Total Fatal NAN instances to confirm this theory

# %%
cleaned_injury_data[cleaned_injury_data['Total.Fatal.Injuries'].isna()]
# Out:
#              Event.Id Accident.Number Aircraft.Category  \
# 5      20170710X52551      NYC79AA106          Airplane
# 89     20020917X02486      NYC82DA022               NaN
# 260    20020917X02495      NYC82DA033          Airplane
# 351    20020917X02151      FTW82IA062          Airplane
# 728    20020917X02383      MIA82DA098               NaN
# ...               ...             ...               ...
# 63904  20080215X00200      CHI08CA058          Airplane
# 63905  20080214X00193      CHI08CA056          Airplane
# 63910  20080129X00122      CHI08CA057          Airplane
# 63911  20080125X00106      SEA08CA056          Airplane
# 63912  20080206X00141      CHI08WA075               NaN
#
#                                  Make      Model  Number.of.Engines  \
# 5                   Mcdonnell Douglas        Dc9                2.0
# 89                             Cessna        310                2.0
# 260                          Bellanca      7Kcab                1.0
# ...

# %%
#as you can see, this seems to be true

# %%
#lets create a new column named 'Fatal Flight?' that simply calls 
#out if an incident had a fatal result or not. We can do this by 
#saying 'Fatal' if the value in Total.Fatal.Injuries column >= 1. 
#If this value is not >= 1 then the new column will display 
#'Not Fatal'

# %%
#We will be able to use this column to do different analyses on
#the safety of the different flying vehicles. In these analyses, 
#safety is denoted by whether a flight was fatal or not.

# %%
#the new column will be called 'incident severity'

# %%
cleaned_injury_data['Incident.Severity']=cleaned_injury_data['Total.Fatal.Injuries'].map(lambda x: 1 if x >= 1 else 0)

# %%
cleaned_injury_data.head()
# Out:
#          Event.Id Accident.Number Aircraft.Category      Make     Model  \
# 0  20001218X45444      SEA87LA080               NaN   Stinson     108-3
# 1  20001218X45447      LAX94LA336               NaN     Piper  Pa24-180
# 2  20061025X01555      NYC07LA005               NaN    Cessna      172M
# 3  20001218X45448      LAX96LA321               NaN  Rockwell       112
# 4  20041105X01764      CHI79FA064               NaN    Cessna       501
#
#    Number.of.Engines    Engine.Type Purpose.of.flight  Total.Fatal.Injuries  \
# 0                1.0  Reciprocating          Personal                   2.0
# 1                1.0  Reciprocating          Personal                   4.0
# 2                1.0  Reciprocating          Personal                   3.0
# 3                1.0  Reciprocating          Personal                   2.0
# 4                NaN            NaN          Personal                   1.0
#
#    Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured  \
# ...

# %%
cleaned_injury_data['Incident.Severity'].value_counts()
# Out:
# Incident.Severity
# 0    69345
# 1    17813
# Name: count, dtype: int64

# %%
cleaned_injury_data['Accident.Number'].value_counts()
# Out:
# Accident.Number
# DCA22LA201    2
# DCA23WA071    2
# WPR23LA045    2
# DCA22WA089    2
# CEN22LA346    2
#              ..
# ATL91LA173    1
# LAX91LA396    1
# NYC91LA238    1
# ANC91FA147    1
# ERA23LA097    1
# Name: count, Length: 87134, dtype: int64

# %%
##now that I have created a df with the new column that I would like I need to split that
#dataframe into three new dataframes for analysis

# %%
#the first dataframe will compare different types of engines to see which ones have the
#lowest associated fatality rates

# %%
#the second dataframe will compare the number of engines types of engines to see if the 
#number of engines effects the fatality rate

# %%
#the third dataframe will compare the make and model of the flying vehicles to 
#see which of those have the lowest fatality rate

# %%
#lets start transforming the data into a engine type data set and then cleaning it

# %%
cleaned_injury_data.columns
# Out:
# Index(['Event.Id', 'Accident.Number', 'Aircraft.Category', 'Make', 'Model',
#        'Number.of.Engines', 'Engine.Type', 'Purpose.of.flight',
#        'Total.Fatal.Injuries', 'Total.Serious.Injuries',
#        'Total.Minor.Injuries', 'Total.Uninjured', 'Incident.Severity'],
#       dtype='object')

# %%
Engine_Type=cleaned_injury_data[['Event.Id', 'Accident.Number', 'Engine.Type', 'Incident.Severity']].copy()

# %%
Engine_Type.head()
# Out:
#          Event.Id Accident.Number    Engine.Type  Incident.Severity
# 0  20001218X45444      SEA87LA080  Reciprocating                  1
# 1  20001218X45447      LAX94LA336  Reciprocating                  1
# 2  20061025X01555      NYC07LA005  Reciprocating                  1
# 3  20001218X45448      LAX96LA321  Reciprocating                  1
# 4  20041105X01764      CHI79FA064            NaN                  1

# %%
#now lets explore this new df to see the best way to clean it

# %%
Engine_Type.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87158 entries, 0 to 90347
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Event.Id           87158 non-null  object
#  1   Accident.Number    87158 non-null  object
#  2   Engine.Type        80266 non-null  object
#  3   Incident.Severity  87158 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 3.3+ MB

# %%
Engine_Type.groupby(['Event.Id','Accident.Number']).count()
# Out:
#                                 Engine.Type  Incident.Severity
# Event.Id       Accident.Number
# 20001204X00000 ANC99FA021                 1                  1
# 20001204X00001 ANC99IA025                 1                  1
# 20001204X00002 ANC99LA020                 1                  1
# 20001204X00003 ANC99LA022                 1                  1
# 20001204X00004 ANC99LA023                 1                  1
# ...                                     ...                ...
# 20221227106496 WPR23LA074                 0                  1
# 20221227106497 WPR23LA075                 0                  1
# 20221227106498 WPR23LA076                 0                  1
# 20221228106502 GAA23WA046                 0                  1
# 20221230106513 ERA23LA097                 0                  1
#
# [87134 rows x 2 columns]

# %%
Engine_Type[Engine_Type.duplicated]
# Out:
#              Event.Id Accident.Number    Engine.Type  Incident.Severity
# 88568  20220111104514      ERA22LA103  Reciprocating                  0
# 88599  20220309104747      DCA22WA089            NaN                  0
# 88620  20220801105632      DCA22WA167            NaN                  0
# 88695  20220212104630      ERA22LA119  Reciprocating                  0
# 89300  20220614105258      DCA22WA130            NaN                  0
# 89384  20220623105317      DCA22LA135            NaN                  0
# 89494  20220726105577      DCA22WA158            NaN                  0
# 89505  20220804105661      DCA22WA172            NaN                  0
# 89587  20220802105640      GAA22WA241            NaN                  0
# 89594  20220718105496      ERA22FA318            NaN                  1
# 89668  20220727105589      ERA22FA338            NaN                  1
# 89687  20220730105623      CEN22LA346  Reciprocating                  0
# ...

# %%
Engine_Type.drop_duplicates(inplace=True)

# %%
#since there are not any repeat Event Id's and Accident numbers that can help us interprat what the NAN might be
#the best way to mitigate the bias in analysis would be to delete them instead of imputing them

# %%
Engine_Type_Scrubbed=Engine_Type.dropna(subset=['Engine.Type']).copy()

# %%
#check out the new dataset

# %%
Engine_Type_Scrubbed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 80263 entries, 0 to 90226
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Event.Id           80263 non-null  object
#  1   Accident.Number    80263 non-null  object
#  2   Engine.Type        80263 non-null  object
#  3   Incident.Severity  80263 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 3.1+ MB

# %%
#this new dataframe is now ready for analysis

# %%
#Start by grouping Incident Severity by Engine Type

# %%
Fatal_Engine_Count_Series=Engine_Type_Scrubbed.groupby(['Engine.Type'])['Incident.Severity'].sum()

# %%
type(Fatal_Engine_Count_Series)
# Out:
# pandas.core.series.Series

# %%
#convert this series to a datadrame

# %%
Engine_Fatality_Count=Fatal_Engine_Count_Series.to_frame()

# %%
Engine_Fatality_Count
# Out:
#                  Incident.Severity
# Engine.Type
# Electric                         2
# Geared Turbofan                  0
# Hybrid Rocket                    1
# LR                               0
# NONE                             0
# Reciprocating                13148
# Turbo Fan                      198
# Turbo Jet                      136
# Turbo Prop                     815
# Turbo Shaft                    799
# UNK                              0
# Unknown                        444

# %%
#rename the count column

# %%
Engine_Fatality_Count.rename(columns={'Incident.Severity': 'Fatality.Count'},inplace=True)

# %%
Engine_Fatality_Count
# Out:
#                  Fatality.Count
# Engine.Type
# Electric                      2
# Geared Turbofan               0
# Hybrid Rocket                 1
# LR                            0
# NONE                          0
# Reciprocating             13148
# Turbo Fan                   198
# Turbo Jet                   136
# Turbo Prop                  815
# Turbo Shaft                 799
# UNK                           0
# Unknown                     444

# %%
#compare these numbers to the total instances of each type of motor

# %%
Engine_Type_Count_Series=Engine_Type_Scrubbed['Engine.Type'].value_counts()

# %%
type(Engine_Type_Count_Series)
# Out:
# pandas.core.series.Series

# %%
#convert this series to a dataframe

# %%
Engine_Count=Engine_Type_Count_Series.to_frame()

# %%
Engine_Count
# Out:
#                  count
# Engine.Type
# Reciprocating    68251
# Turbo Shaft       3523
# Turbo Prop        3325
# Turbo Fan         2463
# Unknown           1972
# Turbo Jet          701
# Geared Turbofan     12
# Electric            10
# LR                   2
# NONE                 2
# Hybrid Rocket        1
# UNK                  1

# %%
#rename the count column

# %%
Engine_Count.rename(columns={'count': 'Incident.Count'},inplace=True)

# %%
Engine_Count
# Out:
#                  Incident.Count
# Engine.Type
# Reciprocating             68251
# Turbo Shaft                3523
# Turbo Prop                 3325
# Turbo Fan                  2463
# Unknown                    1972
# Turbo Jet                   701
# Geared Turbofan              12
# Electric                     10
# LR                            2
# NONE                          2
# Hybrid Rocket                 1
# UNK                           1

# %%
#Merge the two new DataFrames along the shared index

# %%
Engine_Fatality_Analysis=Engine_Fatality_Count.join(Engine_Count, how='inner')

# %%
Engine_Fatality_Analysis
# Out:
#                  Fatality.Count  Incident.Count
# Engine.Type
# Electric                      2              10
# Geared Turbofan               0              12
# Hybrid Rocket                 1               1
# LR                            0               2
# NONE                          0               2
# Reciprocating             13148           68251
# Turbo Fan                   198            2463
# Turbo Jet                   136             701
# Turbo Prop                  815            3325
# Turbo Shaft                 799            3523
# UNK                           0               1
# Unknown                     444            1972

# %%
#get rid of the unknown column row

# %%
Engine_Fatality_Analysis.drop(index='Unknown', inplace=True)

# %%
Engine_Fatality_Analysis
# Out:
#                  Fatality.Count  Incident.Count
# Engine.Type
# Electric                      2              10
# Geared Turbofan               0              12
# Hybrid Rocket                 1               1
# LR                            0               2
# NONE                          0               2
# Reciprocating             13148           68251
# Turbo Fan                   198            2463
# Turbo Jet                   136             701
# Turbo Prop                  815            3325
# Turbo Shaft                 799            3523
# UNK                           0               1

# %%
##Now to conduct the same data manipulation and dataframe creation for
#number of engines vs Fatalities

# %%
cleaned_injury_data.columns
# Out:
# Index(['Event.Id', 'Accident.Number', 'Aircraft.Category', 'Make', 'Model',
#        'Number.of.Engines', 'Engine.Type', 'Purpose.of.flight',
#        'Total.Fatal.Injuries', 'Total.Serious.Injuries',
#        'Total.Minor.Injuries', 'Total.Uninjured', 'Incident.Severity'],
#       dtype='object')

# %%
Engine_Count=cleaned_injury_data[['Event.Id','Accident.Number','Number.of.Engines','Incident.Severity']].copy()

# %%
Engine_Count.head()
# Out:
#          Event.Id Accident.Number  Number.of.Engines  Incident.Severity
# 0  20001218X45444      SEA87LA080                1.0                  1
# 1  20001218X45447      LAX94LA336                1.0                  1
# 2  20061025X01555      NYC07LA005                1.0                  1
# 3  20001218X45448      LAX96LA321                1.0                  1
# 4  20041105X01764      CHI79FA064                NaN                  1

# %%
Engine_Count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87158 entries, 0 to 90347
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Event.Id           87158 non-null  object
#  1   Accident.Number    87158 non-null  object
#  2   Number.of.Engines  81305 non-null  float64
#  3   Incident.Severity  87158 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.3+ MB

# %%
#only around 6% of the number of engine data is missing

# %%
Engine_Count.groupby(['Event.Id','Accident.Number']).count()
# Out:
#                                 Number.of.Engines  Incident.Severity
# Event.Id       Accident.Number
# 20001204X00000 ANC99FA021                       1                  1
# 20001204X00001 ANC99IA025                       1                  1
# 20001204X00002 ANC99LA020                       1                  1
# 20001204X00003 ANC99LA022                       1                  1
# 20001204X00004 ANC99LA023                       1                  1
# ...                                           ...                ...
# 20221227106496 WPR23LA074                       0                  1
# 20221227106497 WPR23LA075                       1                  1
# 20221227106498 WPR23LA076                       0                  1
# 20221228106502 GAA23WA046                       0                  1
# 20221230106513 ERA23LA097                       0                  1
#
# [87134 rows x 2 columns]

# %%
Engine_Count_Scrubbed=Engine_Count.dropna(subset=['Number.of.Engines']).copy()

# %%
Engine_Count_Scrubbed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 81305 entries, 0 to 90345
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Event.Id           81305 non-null  object
#  1   Accident.Number    81305 non-null  object
#  2   Number.of.Engines  81305 non-null  float64
#  3   Incident.Severity  81305 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.1+ MB

# %%
Engine_Count_Scrubbed[Engine_Count_Scrubbed.duplicated]
# Out:
#              Event.Id Accident.Number  Number.of.Engines  Incident.Severity
# 88568  20220111104514      ERA22LA103                1.0                  0
# 88695  20220212104630      ERA22LA119                1.0                  0
# 88856  20220323104818      CEN22LA149                1.0                  0
# 89384  20220623105317      DCA22LA135                2.0                  0
# 89594  20220718105496      ERA22FA318                1.0                  1
# 89668  20220727105589      ERA22FA338                1.0                  1
# 89687  20220730105623      CEN22LA346                1.0                  0
# 89751  20220808105682      ERA22LA364                1.0                  0
# 89992  20220918105957      CEN22FA424                1.0                  1
# 90255  20221121106336      WPR23LA041                1.0                  0
# 90273  20221123106354      WPR23LA045                2.0                  0

# %%
Engine_Count_Scrubbed.drop_duplicates(inplace=True)

# %%
Engine_Count_Scrubbed_Series=Engine_Count_Scrubbed.groupby(['Number.of.Engines'])['Incident.Severity'].sum()

# %%
Engine_Count_Scrubbed_Series
# Out:
# Number.of.Engines
# 0.0      165
# 1.0    12758
# 2.0     2756
# 3.0       24
# 4.0       56
# 6.0        0
# 8.0        0
# Name: Incident.Severity, dtype: int64

# %%
Num_of_Fatal_Engine_Count=Engine_Count_Scrubbed_Series.to_frame()

# %%
Num_of_Fatal_Engine_Count
# Out:
#                    Incident.Severity
# Number.of.Engines
# 0.0                              165
# 1.0                            12758
# 2.0                             2756
# 3.0                               24
# 4.0                               56
# 6.0                                0
# 8.0                                0

# %%
Num_of_Fatal_Engine_Count.rename(columns={'Incident.Severity': 'Fatality.Count'},inplace=True)

# %%
Num_of_Fatal_Engine_Count
# Out:
#                    Fatality.Count
# Number.of.Engines
# 0.0                           165
# 1.0                         12758
# 2.0                          2756
# 3.0                            24
# 4.0                            56
# 6.0                             0
# 8.0                             0

# %%
Engine_Count_Scrubbed_Series=Engine_Count_Scrubbed['Number.of.Engines'].value_counts()

# %%
Engine_Count_Scrubbed_Series
# Out:
# Number.of.Engines
# 1.0    68215
# 2.0    10996
# 0.0     1172
# 3.0      482
# 4.0      425
# 8.0        3
# 6.0        1
# Name: count, dtype: int64

# %%
Total_Engines_Count=Engine_Count_Scrubbed_Series.to_frame()

# %%
Total_Engines_Count
# Out:
#                    count
# Number.of.Engines
# 1.0                68215
# 2.0                10996
# 0.0                 1172
# 3.0                  482
# 4.0                  425
# 8.0                    3
# 6.0                    1

# %%
Total_Engines_Count.rename(columns={'count': 'Incident.Count'},inplace=True)

# %%
Total_Engines_Count
# Out:
#                    Incident.Count
# Number.of.Engines
# 1.0                         68215
# 2.0                         10996
# 0.0                          1172
# 3.0                           482
# 4.0                           425
# 8.0                             3
# 6.0                             1

# %%
Number_of_Engine_Analysis=Num_of_Fatal_Engine_Count.join(Total_Engines_Count, how='inner')

# %%
Number_of_Engine_Analysis
# Out:
#                    Fatality.Count  Incident.Count
# Number.of.Engines
# 0.0                           165            1172
# 1.0                         12758           68215
# 2.0                          2756           10996
# 3.0                            24             482
# 4.0                            56             425
# 6.0                             0               1
# 8.0                             0               3

# %%
###now lets do the same for make and model fatality analysis

# %%
cleaned_injury_data.columns
# Out:
# Index(['Event.Id', 'Accident.Number', 'Aircraft.Category', 'Make', 'Model',
#        'Number.of.Engines', 'Engine.Type', 'Purpose.of.flight',
#        'Total.Fatal.Injuries', 'Total.Serious.Injuries',
#        'Total.Minor.Injuries', 'Total.Uninjured', 'Incident.Severity'],
#       dtype='object')

# %%
Fatal_Model_Count=cleaned_injury_data[['Event.Id','Accident.Number','Make','Model','Incident.Severity']].copy()

# %%
Fatal_Model_Count.head()
# Out:
#          Event.Id Accident.Number      Make     Model  Incident.Severity
# 0  20001218X45444      SEA87LA080   Stinson     108-3                  1
# 1  20001218X45447      LAX94LA336     Piper  Pa24-180                  1
# 2  20061025X01555      NYC07LA005    Cessna      172M                  1
# 3  20001218X45448      LAX96LA321  Rockwell       112                  1
# 4  20041105X01764      CHI79FA064    Cessna       501                  1

# %%
Fatal_Model_Count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87158 entries, 0 to 90347
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Event.Id           87158 non-null  object
#  1   Accident.Number    87158 non-null  object
#  2   Make               87099 non-null  object
#  3   Model              87071 non-null  object
#  4   Incident.Severity  87158 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 4.0+ MB

# %%
Fatal_Model_Count.sort_values(['Event.Id','Accident.Number']).asceding=(True)

# %%
Fatal_Model_Count.groupby(['Event.Id','Accident.Number']).count()
# Out:
#                                 Make  Model  Incident.Severity
# Event.Id       Accident.Number
# 20001204X00000 ANC99FA021          1      1                  1
# 20001204X00001 ANC99IA025          1      1                  1
# 20001204X00002 ANC99LA020          1      1                  1
# 20001204X00003 ANC99LA022          1      1                  1
# 20001204X00004 ANC99LA023          1      1                  1
# ...                              ...    ...                ...
# 20221227106496 WPR23LA074          1      1                  1
# 20221227106497 WPR23LA075          1      1                  1
# 20221227106498 WPR23LA076          1      1                  1
# 20221228106502 GAA23WA046          1      1                  1
# 20221230106513 ERA23LA097          1      1                  1
#
# [87134 rows x 3 columns]

# %%
Fatal_Model_Count.groupby(['Event.Id','Accident.Number']).count().value_counts()
# Out:
# Make  Model  Incident.Severity
# 1     1      1                    87004
#       0      1                       47
# 0     0      1                       40
# 2     2      2                       24
# 0     1      1                       19
# Name: count, dtype: int64

# %%
Fatal_Model_Count[Fatal_Model_Count.duplicated]
# Out:
#              Event.Id Accident.Number    Make Model  Incident.Severity
# 88856  20220323104818      CEN22LA149  Cessna  208B                  0

# %%
Fatal_Model_Count
# Out:
#              Event.Id Accident.Number                        Make      Model  \
# 0      20001218X45444      SEA87LA080                     Stinson      108-3
# 1      20001218X45447      LAX94LA336                       Piper   Pa24-180
# 2      20061025X01555      NYC07LA005                      Cessna       172M
# 3      20001218X45448      LAX96LA321                    Rockwell        112
# 4      20041105X01764      CHI79FA064                      Cessna        501
# ...               ...             ...                         ...        ...
# 90343  20221227106491      ERA23LA093                       Piper  Pa-28-151
# 90344  20221227106494      ERA23LA095                    Bellanca       7Eca
# 90345  20221227106497      WPR23LA075  American Champion Aircraft      8Gcbc
# 90346  20221227106498      WPR23LA076                      Cessna       210N
# 90347  20221230106513      ERA23LA097                       Piper  Pa-24-260
#
#        Incident.Severity
# ...

# %%
Fatal_Model_Count.drop_duplicates(inplace=True)

# %%
Fatal_Model_Count_Scrubbed=Fatal_Model_Count.dropna(subset=['Model'])

# %%
Fatal_Model_Count_Scrubbed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87070 entries, 0 to 90347
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Event.Id           87070 non-null  object
#  1   Accident.Number    87070 non-null  object
#  2   Make               87051 non-null  object
#  3   Model              87070 non-null  object
#  4   Incident.Severity  87070 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 4.0+ MB

# %%
Fatal_Model_Count_Series=Fatal_Model_Count_Scrubbed.groupby(['Model'])['Incident.Severity'].sum()

# %%
Fatal_Model_Count_DF=Fatal_Model_Count_Series.to_frame()

# %%
Fatal_Model_Count_DF
# Out:
#                      Incident.Severity
# Model
# &Gcbc                                0
# (Ex) Rv-6                            1
# (Modified)                           1
# (Soloy Conversion)                   0
# -269C                                0
# ...                                ...
# Zuber Super Drifter                  0
# Zugvogel Iiib                        0
# Zuni                                 1
# Zuni 2                               1
# Zuni Ii                              0
#
# [11464 rows x 1 columns]

# %%
Fatal_Model_Count_DF.rename(columns={'Incident.Severity':'Fatality.Count'},inplace=True)

# %%
Fatal_Model_Count_DF.sort_values('Fatality.Count',ascending=False)
# Out:
#                 Fatality.Count
# Model
# 152                        251
# 172                        212
# 172N                       204
# Pa-28-140                  182
# A36                        159
# ...                        ...
# Discovery S-12               0
# Discovery                    0
# Dickey E-Racer               0
# Diamond                      0
# Zuni Ii                      0
#
# [11464 rows x 1 columns]

# %%
Fatal_Make_Count_Scrubbed=Fatal_Model_Count.dropna(subset=['Make'])

# %%
Fatal_Make_Count_Scrubbed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87098 entries, 0 to 90347
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Event.Id           87098 non-null  object
#  1   Accident.Number    87098 non-null  object
#  2   Make               87098 non-null  object
#  3   Model              87051 non-null  object
#  4   Incident.Severity  87098 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 4.0+ MB

# %%
Fatal_Make_Count_Series=Fatal_Make_Count_Scrubbed.groupby(['Make'])['Incident.Severity'].sum()

# %%
Fatal_Make_Count_DF=Fatal_Make_Count_Series.to_frame()

# %%
Fatal_Make_Count_DF
# Out:
#                           Incident.Severity
# Make
# 107.5 Flying Corporation                  1
# 1200                                      0
# 177Mf Llc                                 0
# 1St Ftr Gp                                1
# 2000 Mccoy                                1
# ...                                     ...
# Zubair S Khan                             1
# Zuber Thomas P                            0
# Zukowski                                  0
# Zwart                                     0
# Zwicker Murray R                          0
#
# [7400 rows x 1 columns]

# %%
Fatal_Make_Count_DF.rename(columns={'Incident.Severity': 'Fatality.Count'}, inplace=True)

# %%
Fatal_Make_Count_DF
# Out:
#                           Fatality.Count
# Make
# 107.5 Flying Corporation               1
# 1200                                   0
# 177Mf Llc                              0
# 1St Ftr Gp                             1
# 2000 Mccoy                             1
# ...                                  ...
# Zubair S Khan                          1
# Zuber Thomas P                         0
# Zukowski                               0
# Zwart                                  0
# Zwicker Murray R                       0
#
# [7400 rows x 1 columns]

# %%
Fatal_Make_Count_DF.sort_values('Fatality.Count',ascending=False)
# Out:
#                   Fatality.Count
# Make
# Cessna                      4636
# Piper                       3204
# Beech                       1575
# Bell                         583
# Mooney                       376
# ...                          ...
# Heinemann                      0
# Heindenreich                   0
# Hein                           0
# Hegsted                        0
# Zwicker Murray R               0
#
# [7400 rows x 1 columns]

# %%
Fatal_Make_Count_DF.sort_values('Fatality.Count',ascending=False).head(10)
# Out:
#           Fatality.Count
# Make
# Cessna              4636
# Piper               3204
# Beech               1575
# Bell                 583
# Mooney               376
# Robinson             349
# Bellanca             214
# Boeing               167
# Hughes               136
# Grumman              131

# %%
Total_Make_Count_DF=Fatal_Make_Count_Scrubbed['Make'].value_counts().to_frame()

# %%
Total_Make_Count_DF
# Out:
#                           count
# Make
# Cessna                    26728
# Piper                     14671
# Beech                      5302
# Bell                       2654
# Boeing                     2621
# ...                         ...
# Harry Tomlinson               1
# John Hubbard                  1
# Lakeland Ultralites Inc.      1
# Larson Smith Miniplane        1
# Royse Ralph L                 1
#
# [7400 rows x 1 columns]

# %%
Total_Make_Count_DF.rename(columns={'count': 'Make.Count'}, inplace=True)

# %%
Total_Model_Count_DF=Fatal_Model_Count_Scrubbed['Model'].value_counts().to_frame()

# %%
Total_Model_Count_DF
# Out:
#               count
# Model
# 152            2339
# 172            1743
# 172N           1144
# Pa-28-140       912
# 150             818
# ...             ...
# Bl-26             1
# 206L-1/C-30P      1
# Horizon One       1
# Dc-10-10Cf        1
# M-8 Eagle         1
#
# [11464 rows x 1 columns]

# %%
Total_Model_Count_DF.rename(columns={'count': 'Model.Count'}, inplace=True)

# %%
Fatal_Make_Analysis=Fatal_Make_Count_DF.join(Total_Make_Count_DF, how='inner')

# %%
Fatal_Make_Analysis
# Out:
#                           Fatality.Count  Make.Count
# Make
# 107.5 Flying Corporation               1           1
# 1200                                   0           1
# 177Mf Llc                              0           1
# 1St Ftr Gp                             1           1
# 2000 Mccoy                             1           1
# ...                                  ...         ...
# Zubair S Khan                          1           1
# Zuber Thomas P                         0           1
# Zukowski                               0           1
# Zwart                                  0           1
# Zwicker Murray R                       0           1
#
# [7400 rows x 2 columns]

# %%
Fatal_Model_Analysis=Fatal_Model_Count_DF.join(Total_Model_Count_DF, how='inner')

# %%
Fatal_Model_Analysis
# Out:
#                      Fatality.Count  Model.Count
# Model
# &Gcbc                             0            1
# (Ex) Rv-6                         1            1
# (Modified)                        1            1
# (Soloy Conversion)                0            1
# -269C                             0            1
# ...                             ...          ...
# Zuber Super Drifter               0            1
# Zugvogel Iiib                     0            1
# Zuni                              1            5
# Zuni 2                            1            1
# Zuni Ii                           0            1
#
# [11464 rows x 2 columns]

# %%
Fatal_Model_Analysis.sort_values(by=['Model.Count'], ascending=False, inplace=True)

# %%
Fatal_Model_Analysis
# Out:
#               Fatality.Count  Model.Count
# Model
# 152                      251         2339
# 172                      212         1743
# 172N                     204         1144
# Pa-28-140                182          912
# 150                       89          818
# ...                      ...          ...
# Easy Raider                0            1
# Easy Eagle 1               0            1
# Easy Eagle                 1            1
# East Riser                 1            1
# Zuni Ii                    0            1
#
# [11464 rows x 2 columns]

# %%
Fatal_Make_Analysis.sort_values(by=['Make.Count'], ascending=False, inplace=True)

# %%
Fatal_Make_Analysis
# Out:
#                   Fatality.Count  Make.Count
# Make
# Cessna                      4636       26728
# Piper                       3204       14671
# Beech                       1575        5302
# Bell                         583        2654
# Boeing                       167        2621
# ...                          ...         ...
# Haas                           0           1
# H. Raymond                     0           1
# H. Preiss                      1           1
# Gyroflug                       1           1
# Zwicker Murray R               0           1
#
# [7400 rows x 2 columns]

# %%
##now that all of the analysis dataframnes have been prepared
#lets turn them into visual representations

# %%
#call down all the datasets

# %%
Fatal_Make_Analysis
# Out:
#                   Fatality.Count  Make.Count
# Make
# Cessna                      4636       26728
# Piper                       3204       14671
# Beech                       1575        5302
# Bell                         583        2654
# Boeing                       167        2621
# ...                          ...         ...
# Haas                           0           1
# H. Raymond                     0           1
# H. Preiss                      1           1
# Gyroflug                       1           1
# Zwicker Murray R               0           1
#
# [7400 rows x 2 columns]

# %%
Fatal_Model_Analysis
# Out:
#               Fatality.Count  Model.Count
# Model
# 152                      251         2339
# 172                      212         1743
# 172N                     204         1144
# Pa-28-140                182          912
# 150                       89          818
# ...                      ...          ...
# Easy Raider                0            1
# Easy Eagle 1               0            1
# Easy Eagle                 1            1
# East Riser                 1            1
# Zuni Ii                    0            1
#
# [11464 rows x 2 columns]

# %%
Number_of_Engine_Analysis.sort_values(by=['Incident.Count'], ascending=False, inplace=True)

# %%
Number_of_Engine_Analysis
# Out:
#                    Fatality.Count  Incident.Count
# Number.of.Engines
# 1.0                         12758           68215
# 2.0                          2756           10996
# 0.0                           165            1172
# 3.0                            24             482
# 4.0                            56             425
# 8.0                             0               3
# 6.0                             0               1

# %%
Engine_Fatality_Analysis.sort_values(by=['Incident.Count'], ascending=False, inplace=True)

# %%
Engine_Fatality_Analysis
# Out:
#                  Fatality.Count  Incident.Count
# Engine.Type
# Reciprocating             13148           68251
# Turbo Shaft                 799            3523
# Turbo Prop                  815            3325
# Turbo Fan                   198            2463
# Turbo Jet                   136             701
# Geared Turbofan               0              12
# Electric                      2              10
# LR                            0               2
# NONE                          0               2
# Hybrid Rocket                 1               1
# UNK                           0               1

# %%
##make a visual representation for the number of engine analysis

# %%
Number_of_Engine_Analysis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, 1.0 to 6.0
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Fatality.Count  7 non-null      int64
#  1   Incident.Count  7 non-null      int64
# dtypes: int64(2)
# memory usage: 168.0 bytes

# %%
Number_of_Engine_Analysis.index=Number_of_Engine_Analysis.index.astype(int)

# %%
Number_of_Engine_Analysis= Number_of_Engine_Analysis.sort_index(axis=0)

# %%
Number_of_Engine_Analysis
# Out:
#                    Fatality.Count  Incident.Count
# Number.of.Engines
# 0                             165            1172
# 1                           12758           68215
# 2                            2756           10996
# 3                              24             482
# 4                              56             425
# 6                               0               1
# 8                               0               3

# %%
Significant_engine_number_analysis= Number_of_Engine_Analysis[Number_of_Engine_Analysis['Fatality.Count']!=0]

# %%
Significant_engine_number_analysis
# Out:
#                    Fatality.Count  Incident.Count
# Number.of.Engines
# 0                             165            1172
# 1                           12758           68215
# 2                            2756           10996
# 3                              24             482
# 4                              56             425

# %%
Significant_engine_number_analysis.loc[:,'Fatality %']=(Significant_engine_number_analysis['Fatality.Count']\
                                         /Significant_engine_number_analysis['Incident.Count'])*100
# Out:
# /var/folders/p_/7g5qyc8d5zv5nfywm65yhpkc0000gn/T/ipykernel_83805/719014054.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Significant_engine_number_analysis.loc[:,'Fatality %']=(Significant_engine_number_analysis['Fatality.Count']\

# %%
Significant_engine_number_analysis
# Out:
#                    Fatality.Count  Incident.Count  Fatality %
# Number.of.Engines
# 0                             165            1172   14.078498
# 1                           12758           68215   18.702631
# 2                            2756           10996   25.063660
# 3                              24             482    4.979253
# 4                              56             425   13.176471

# %%
Significant_engine_number_analysis.loc[:,'Fatality %']= Significant_engine_number_analysis['Fatality %'].round(2)

# %%
Significant_engine_number_analysis.reset_index(inplace=True)

# %%
Significant_engine_number_analysis
# Out:
#    Number.of.Engines  Fatality.Count  Incident.Count  Fatality %
# 0                  0             165            1172       14.08
# 1                  1           12758           68215       18.70
# 2                  2            2756           10996       25.06
# 3                  3              24             482        4.98
# 4                  4              56             425       13.18

# %%
#######HERE is the first prepped DF to Work with ^ "Significant_engine_number_analysis"

# %%
#x= Number_of_Engine_Analysis.index
#x=np.arange(len(Number_of_Engine_Analysis_v2.index))
#y1= Number_of_Engine_Analysis_v2['Fatality.Count']
#y2= Number_of_Engine_Analysis_v2['Incident.Count']

#fig, Backup_Engine_Analysis =plt.subplots()
#Fatal_Incidents_plt=Backup_Engine_Analysis.bar(x,y1)
#Total_Incidents_plt=Backup_Engine_Analysis.bar(x,y2, bottom=y1)

#Backup_Engine_Analysis.set_title('Number of Flight Incidents Compared to Number of Aircraft Engines')
#Backup_Engine_Analysis.set_ylabel('Number of Flight Incidents')
#Backup_Engine_Analysis.set_xlabel('Number of Aircraft Engines')
#Backup_Engine_Analysis.set_xticks(x)
#Backup_Engine_Analysis.set_xticklabels(Number_of_Engine_Analysis_v2.index.astype(int))


#Backup_Engine_Analysis.legend([Fatal_Incidents_plt, Total_Incidents_plt], ['Fatal Incidents', 'Total Incidents'], loc = 'upper right')

# %%
Number_of_Engine_Analysis_v2=Number_of_Engine_Analysis.sort_index(axis=0)

# %%
#import the libraries we need to visualize this

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %%
Number_of_Engine_Analysis_v2
# Out:
#                    Fatality.Count  Incident.Count
# Number.of.Engines
# 0                             165            1172
# 1                           12758           68215
# 2                            2756           10996
# 3                              24             482
# 4                              56             425
# 6                               0               1
# 8                               0               3

# %%
#Maybe we can normalize the data by displaying the data as a percentage of all the incidents, or state what percentage
#of the incidents are fatal compared to the incidents for that category

# %%
#x= Number_of_Engine_Analysis.index
x=np.arange(len(Number_of_Engine_Analysis_v2.index))
y1= Number_of_Engine_Analysis_v2['Fatality.Count']
y2= Number_of_Engine_Analysis_v2['Incident.Count']

fig, Backup_Engine_Analysis =plt.subplots()
Fatal_Incidents_plt=Backup_Engine_Analysis.bar(x,y1)
Total_Incidents_plt=Backup_Engine_Analysis.bar(x,y2, bottom=y1)

Backup_Engine_Analysis.set_title('Number of Flight Incidents Compared to Number of Aircraft Engines')
Backup_Engine_Analysis.set_ylabel('Number of Flight Incidents')
Backup_Engine_Analysis.set_xlabel('Number of Aircraft Engines')
Backup_Engine_Analysis.set_xticks(x)
Backup_Engine_Analysis.set_xticklabels(Number_of_Engine_Analysis_v2.index.astype(int))


Backup_Engine_Analysis.legend([Fatal_Incidents_plt, Total_Incidents_plt], ['Fatal Incidents', 'Total Incidents'], loc = 'upper right')

# %%
df = pd.DataFrame({'High Temp': [28, 30, 34, 38, 45, 42,
                                 38, 35, 32, 28, 25, 21],
                   'Low Temp': [22, 26, 30, 32, 41, 38,
                                32, 31, 28, 22, 15, 15],
                   'Avg Temp': [25, 28, 32, 35, 43, 40, 
                                35, 33, 30, 25, 20, 18]},
                  index=['Jan', 'Feb', 'Mar', 'Apr', 'May',
                         'Jun', 'Jul', 'Aug', 'Sep', 'Oct',
                         'Nov', 'Dec'])
 
 
# create stacked bar chart for monthly temperatures
df.plot(kind='bar', stacked=True, color=['red', 'skyblue', 'green'])
 
# labels for x & y axis
plt.xlabel('Months')
plt.ylabel('Temp ranges in Degree Celsius')
 
# title of plot
plt.title('Monthly Temperatures in a year')
# Out:
# Text(0.5, 1.0, 'Monthly Temperatures in a year')

# %%
df
# Out:
#      High Temp  Low Temp  Avg Temp
# Jan         28        22        25
# Feb         30        26        28
# Mar         34        30        32
# Apr         38        32        35
# May         45        41        43
# Jun         42        38        40
# Jul         38        32        35
# Aug         35        31        33
# Sep         32        28        30
# Oct         28        22        25
# Nov         25        15        20
# Dec         21        15        18

# %%
#HERE is the second dataframe that I shopuld be working with

# %%
Engine_Type_Fatality_Analysis= Engine_Fatality_Analysis

# %%
Engine_Type_Fatality_Analysis
# Out:
#                  Fatality.Count  Incident.Count
# Engine.Type
# Reciprocating             13148           68251
# Turbo Shaft                 799            3523
# Turbo Prop                  815            3325
# Turbo Fan                   198            2463
# Turbo Jet                   136             701
# Geared Turbofan               0              12
# Electric                      2              10
# LR                            0               2
# NONE                          0               2
# Hybrid Rocket                 1               1
# UNK                           0               1

# %%
#Reason for dropping these values

# %%
#given a true population mean, every time you sample from the population, that group will have their own sample mean
#per the central limit theroem as the size of the sample grows the sameple mean will become a better approximation
#of the true population mean since the sampling distrobution of the sampling mean becomes more cenbtralized around
#the true population mean. Therefor for the rows that are under X sample size we are dropping them 
#because they are not statistically significant

# %%
Significant_Engine_Type_Fatality_Analysis= \
    Engine_Type_Fatality_Analysis[Engine_Type_Fatality_Analysis['Fatality.Count']>=136]

# %%
Significant_Engine_Type_Fatality_Analysis
# Out:
#                Fatality.Count  Incident.Count
# Engine.Type
# Reciprocating           13148           68251
# Turbo Shaft               799            3523
# Turbo Prop                815            3325
# Turbo Fan                 198            2463
# Turbo Jet                 136             701

# %%
Significant_Engine_Type_Fatality_Analysis.loc[:,'Fatality %']=\
    (Significant_Engine_Type_Fatality_Analysis['Incident.Count']/\
    Significant_Engine_Type_Fatality_Analysis['Fatality.Count']).round(2)
# Out:
# /var/folders/p_/7g5qyc8d5zv5nfywm65yhpkc0000gn/T/ipykernel_83805/2498870745.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Significant_Engine_Type_Fatality_Analysis.loc[:,'Fatality %']=\

# %%
Significant_Engine_Type_Fatality_Analysis
# Out:
#                Fatality.Count  Incident.Count  Fatality %
# Engine.Type
# Reciprocating           13148           68251        5.19
# Turbo Shaft               799            3523        4.41
# Turbo Prop                815            3325        4.08
# Turbo Fan                 198            2463       12.44
# Turbo Jet                 136             701        5.15

# %%
Significant_Engine_Type_Fatality_Analysis.reset_index(inplace=True)

# %%
Significant_Engine_Type_Fatality_Analysis
# Out:
#      Engine.Type  Fatality.Count  Incident.Count  Fatality %
# 0  Reciprocating           13148           68251        5.19
# 1    Turbo Shaft             799            3523        4.41
# 2     Turbo Prop             815            3325        4.08
# 3      Turbo Fan             198            2463       12.44
# 4      Turbo Jet             136             701        5.15

# %%
####USE THIS DATAFRAME as number two

# %%
#####Third DataFrame Below

# %%
Fatal_Make_Analysis
# Out:
#                   Fatality.Count  Make.Count
# Make
# Cessna                      4636       26728
# Piper                       3204       14671
# Beech                       1575        5302
# Bell                         583        2654
# Boeing                       167        2621
# ...                          ...         ...
# Haas                           0           1
# H. Raymond                     0           1
# H. Preiss                      1           1
# Gyroflug                       1           1
# Zwicker Murray R               0           1
#
# [7400 rows x 2 columns]

# %%
Fatal_Model_Analysis
# Out:
#               Fatality.Count  Model.Count
# Model
# 152                      251         2339
# 172                      212         1743
# 172N                     204         1144
# Pa-28-140                182          912
# 150                       89          818
# ...                      ...          ...
# Easy Raider                0            1
# Easy Eagle 1               0            1
# Easy Eagle                 1            1
# East Riser                 1            1
# Zuni Ii                    0            1
#
# [11464 rows x 2 columns]

# %%
#step 0 plot a histgram of the counts to see when I should do the cutoff (maybe around 100)
#step 1 drop what we dont have ample sample size for 
#step calculate the fatality proportions (new column)
#step 3 calculate the dataset statistics 
#step 4 from the average create 2 subsets of data: highest fatality rates and the lowest fatality rates /
#use .tail to grab the bottom of a data set 
#(with both showing a vertical line for the average)

# %%
Fatal_Make_Analysis.reset_index(inplace=True)

# %%
Trimmed_Make_Analysis=Fatal_Make_Analysis[Fatal_Make_Analysis['Make.Count']>=100]

# %%
sns.lineplot(data=Fatal_Make_Analysis.head(10), x='Make', y='Make.Count')
# Out:
# <Axes: xlabel='Make', ylabel='Make.Count'>

# %%
sns.lineplot(data= Trimmed_Make_Analysis, x='Make', y='Make.Count')
# Out:
# <Axes: xlabel='Make', ylabel='Make.Count'>

# %%
Trimmed_Make_Analysis.loc[:,'Make.Fatality.Percentage']=(Trimmed_Make_Analysis['Fatality.Count']/\
                                                          Trimmed_Make_Analysis['Make.Count']).round(2)*100
# Out:
# /var/folders/p_/7g5qyc8d5zv5nfywm65yhpkc0000gn/T/ipykernel_83805/860037254.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Trimmed_Make_Analysis.loc[:,'Make.Fatality.Percentage']=(Trimmed_Make_Analysis['Fatality.Count']/\

# %%
Trimmed_Make_Analysis['Make.Fatality.Percentage'].describe()
# Out:
# count    59.000000
# mean     18.813559
# std       9.160399
# min       4.000000
# 25%      12.000000
# 50%      18.000000
# 75%      24.000000
# max      42.000000
# Name: Make.Fatality.Percentage, dtype: float64

# %%
Trimmed_Make_Analysis['Make.Fatality.Percentage'].value_counts()
# Out:
# Make.Fatality.Percentage
# 12.0    5
# 17.0    4
# 15.0    4
# 22.0    4
# 18.0    4
# 7.0     3
# 32.0    3
# 21.0    2
# 24.0    2
# 8.0     2
# 19.0    2
# 9.0     2
# 5.0     2
# 20.0    2
# 28.0    2
# 29.0    2
# 11.0    2
# 6.0     1
# 23.0    1
# 30.0    1
# 13.0    1
# 14.0    1
# 27.0    1
# 33.0    1
# 42.0    1
# 4.0     1
# 31.0    1
# 35.0    1
# 39.0    1
# Name: count, dtype: int64

# %%
Top_Performing_Makes=Trimmed_Make_Analysis.sort_values('Make.Fatality.Percentage').head(10)

# %%
############## Use this dataframe

# %%
Top_Performing_Makes
# Out:
#                  Make  Fatality.Count  Make.Count  Make.Fatality.Percentage
# 47               Waco               6         141                       4.0
# 26             Airbus              15         289                       5.0
# 55  Grumman-Schweizer               6         116                       5.0
# 4              Boeing             167        2621                       6.0
# 24             Hiller              23         343                       7.0
# 48                Let              10         135                       7.0
# 43      Balloon Works              10         147                       7.0
# 56              Helio               9         113                       8.0
# 40   Airbus Industrie              12         154                       8.0
# 10          Schweizer              71         757                       9.0

# %%
Worst_Performing_Makes=Trimmed_Make_Analysis.sort_values('Make.Fatality.Percentage').tail(10)

# %%
##########Use this data frame

# %%
Worst_Performing_Makes
# Out:
#                   Make  Fatality.Count  Make.Count  Make.Fatality.Percentage
# 5               Mooney             376        1297                      29.0
# 2                Beech            1575        5302                      30.0
# 49             Learjet              42         135                      31.0
# 32  Cirrus Design Corp              72         223                      32.0
# 21      North American             122         381                      32.0
# 53            Lockheed              38         119                      32.0
# 42              Cirrus              50         150                      33.0
# 51                Vans              45         128                      35.0
# 52              Socata              48         124                      39.0
# 45          Mitsubishi              61         145                      42.0

# %%
##now for models dataframe

# %%
Fatal_Model_Analysis
# Out:
#               Fatality.Count  Model.Count
# Model
# 152                      251         2339
# 172                      212         1743
# 172N                     204         1144
# Pa-28-140                182          912
# 150                       89          818
# ...                      ...          ...
# Easy Raider                0            1
# Easy Eagle 1               0            1
# Easy Eagle                 1            1
# East Riser                 1            1
# Zuni Ii                    0            1
#
# [11464 rows x 2 columns]

# %%
Fatal_Model_Analysis.reset_index(inplace=True)

# %%
#step 0 plot a histgram of the counts to see when I should do the cutoff (maybe around 100)
#step 1 drop what we dont have ample sample size for 
#step calculate the fatality proportions (new column)
#step 3 calculate the dataset statistics 
#step 4 from the average create 2 subsets of data: highest fatality rates and the lowest fatality rates /
#use .tail to grab the bottom of a data set 
#(with both showing a vertical line for the average)

# %%
sns.lineplot(data=Fatal_Model_Analysis.head(50), x='Model', y='Model.Count')
# Out:
# <Axes: xlabel='Model', ylabel='Model.Count'>

# %%
sns.lineplot(data=Fatal_Model_Analysis.head(500), x='Model', y='Model.Count')
# Out:
# <Axes: xlabel='Model', ylabel='Model.Count'>

# %%
Fatal_Model_Analysis.head(125)
# Out:
#          Model  Fatality.Count  Model.Count
# 0          152             251         2339
# 1          172             212         1743
# 2         172N             204         1144
# 3    Pa-28-140             182          912
# 4          150              89          818
# ..         ...             ...          ...
# 120       F33A              34          113
# 121      U206G              36          113
# 122        188              11          112
# 123  Pa-34-200              20          111
# 124      Tr182              28          111
#
# [125 rows x 3 columns]

# %%
sns.lineplot(data=Fatal_Model_Analysis.head(125), x='Model', y='Model.Count')
# Out:
# <Axes: xlabel='Model', ylabel='Model.Count'>

# %%
Trimmed_Model_Analysis=Fatal_Model_Analysis[Fatal_Model_Analysis['Model.Count']>=100]

# %%
Trimmed_Model_Analysis.loc[:,'Model.Fatality.Percentage']=(Trimmed_Model_Analysis['Fatality.Count']/\
                                                          Trimmed_Model_Analysis['Model.Count']).round(2)*100
# Out:
# /var/folders/p_/7g5qyc8d5zv5nfywm65yhpkc0000gn/T/ipykernel_83805/843687528.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Trimmed_Model_Analysis.loc[:,'Model.Fatality.Percentage']=(Trimmed_Model_Analysis['Fatality.Count']/\

# %%
Trimmed_Model_Analysis['Model.Fatality.Percentage'].describe()
# Out:
# count    140.000000
# mean      19.914286
# std        9.215631
# min        3.000000
# 25%       13.000000
# 50%       18.000000
# 75%       26.000000
# max       43.000000
# Name: Model.Fatality.Percentage, dtype: float64

# %%
Top_Performing_Models=Trimmed_Model_Analysis.sort_values('Model.Fatality.Percentage').head(10)

# %%
Top_Performing_Models
# Out:
#       Model  Fatality.Count  Model.Count  Model.Fatality.Percentage
# 16      737              16          486                        3.0
# 18   G-164A              22          451                        5.0
# 67    Pa-22              12          199                        6.0
# 104   Pa-20               8          130                        6.0
# 131   G-164               6          105                        6.0
# 128   T188C               7          106                        7.0
# 21   G-164B              28          408                        7.0
# 86      170              11          162                        7.0
# 114   A75N1               8          120                        7.0
# 88   Uh-12E              11          159                        7.0

# %%
Worst_Performing_Models=Trimmed_Model_Analysis.sort_values('Model.Fatality.Percentage').tail(10)

# %%
Worst_Performing_Models
# Out:
#       Model  Fatality.Count  Model.Count  Model.Fatality.Percentage
# 73     208B              65          182                       36.0
# 85    8Kcab              58          162                       36.0
# 139     208              37          100                       37.0
# 26      R44             132          353                       37.0
# 90     M20K              60          158                       38.0
# 52       58              95          252                       38.0
# 105    421C              51          130                       39.0
# 116    310R              48          118                       41.0
# 119    340A              48          115                       42.0
# 118  95-B55              50          117                       43.0

# %%
####Call all the dataframes

# %%
Worst_Performing_Models
# Out:
#       Model  Fatality.Count  Model.Count  Model.Fatality.Percentage
# 73     208B              65          182                       36.0
# 85    8Kcab              58          162                       36.0
# 139     208              37          100                       37.0
# 26      R44             132          353                       37.0
# 90     M20K              60          158                       38.0
# 52       58              95          252                       38.0
# 105    421C              51          130                       39.0
# 116    310R              48          118                       41.0
# 119    340A              48          115                       42.0
# 118  95-B55              50          117                       43.0

# %%
Top_Performing_Models
# Out:
#       Model  Fatality.Count  Model.Count  Model.Fatality.Percentage
# 16      737              16          486                        3.0
# 18   G-164A              22          451                        5.0
# 67    Pa-22              12          199                        6.0
# 104   Pa-20               8          130                        6.0
# 131   G-164               6          105                        6.0
# 128   T188C               7          106                        7.0
# 21   G-164B              28          408                        7.0
# 86      170              11          162                        7.0
# 114   A75N1               8          120                        7.0
# 88   Uh-12E              11          159                        7.0

# %%
Worst_Performing_Makes
# Out:
#                   Make  Fatality.Count  Make.Count  Make.Fatality.Percentage
# 5               Mooney             376        1297                      29.0
# 2                Beech            1575        5302                      30.0
# 49             Learjet              42         135                      31.0
# 32  Cirrus Design Corp              72         223                      32.0
# 21      North American             122         381                      32.0
# 53            Lockheed              38         119                      32.0
# 42              Cirrus              50         150                      33.0
# 51                Vans              45         128                      35.0
# 52              Socata              48         124                      39.0
# 45          Mitsubishi              61         145                      42.0

# %%
Top_Performing_Makes
# Out:
#                  Make  Fatality.Count  Make.Count  Make.Fatality.Percentage
# 47               Waco               6         141                       4.0
# 26             Airbus              15         289                       5.0
# 55  Grumman-Schweizer               6         116                       5.0
# 4              Boeing             167        2621                       6.0
# 24             Hiller              23         343                       7.0
# 48                Let              10         135                       7.0
# 43      Balloon Works              10         147                       7.0
# 56              Helio               9         113                       8.0
# 40   Airbus Industrie              12         154                       8.0
# 10          Schweizer              71         757                       9.0

# %%
Significant_Engine_Type_Fatality_Analysis
# Out:
#      Engine.Type  Fatality.Count  Incident.Count  Fatality %
# 0  Reciprocating           13148           68251        5.19
# 1    Turbo Shaft             799            3523        4.41
# 2     Turbo Prop             815            3325        4.08
# 3      Turbo Fan             198            2463       12.44
# 4      Turbo Jet             136             701        5.15

# %%
Significant_engine_number_analysis.loc[:,'Number.of.Engines']= Significant_engine_number_analysis['Number.of.Engines'].astype(object)

# %%
Significant_engine_number_analysis
# Out:
#   Number.of.Engines  Fatality.Count  Incident.Count  Fatality %
# 0                 0             165            1172       14.08
# 1                 1           12758           68215       18.70
# 2                 2            2756           10996       25.06
# 3                 3              24             482        4.98
# 4                 4              56             425       13.18

# %%
###graph them

# %%
#Graph for Engine Type Analysis

x= Significant_Engine_Type_Fatality_Analysis['Engine.Type']
y= Significant_Engine_Type_Fatality_Analysis['Fatality %']

Engine_Type_Fig, Engine_Type_Axes= plt.subplots()
Engine_Types_plt= Engine_Type_Axes.bar(x,y, color='blue')

for Eng in Engine_Types_plt:
    height= Eng.get_height()
    Engine_Type_Axes.annotate(f'{height}', xy=(Eng.get_x() + Eng.get_width() / 2, height-1), xytext=(0,3),
                              textcoords= 'offset points', ha= 'center', va= 'bottom', color= 'white',
                             fontweight= 'bold')

Engine_Type_Axes.set_title('Fatal Incidents Out Of Total Incidents For Each Engine Type')
Engine_Type_Axes.set_ylabel('Percentage Of Incidents That Are Fatal')
Engine_Type_Axes.set_xlabel('Type Of Aircraft Engines')

Engine_Type_Axes.legend([Engine_Types_plt], ['Fatality Percentage'], loc = 'upper left')

plt.savefig("./images/Engine_Type_Distribution.png", dpi=150)
plt.show()

# %%
#graph for engine count analysis

y=Significant_engine_number_analysis['Number.of.Engines']
x=Significant_engine_number_analysis['Fatality %']

Backup_Engine_Fig, Backup_Engine_Axes= plt.subplots()
Backup_Engine_plt=Backup_Engine_Axes.barh(y,x, color='blue')

for Eng in Backup_Engine_Axes.patches:
    plt.text(Eng.get_width()-3, Eng.get_y()+ 0.3,
             str(round((Eng.get_width()), 2)),
             fontsize= 10, color= 'white',
            fontweight= 'bold')

Backup_Engine_Axes.set_title('Fatal Incidents Out Of Total Incidents For Each Engine Allotment')
Backup_Engine_Axes.set_ylabel('Number Of Aircraft Engines')
Backup_Engine_Axes.set_xlabel('Percentage Of Incidents That Are Fatal For Each Engine Allotment')

Backup_Engine_Axes.legend([Backup_Engine_plt], ['Fatality Percentage'], loc = 'upper right')

plt.savefig("./images/Engine_Count_Distribution.png", dpi=150)
plt.show()

# %%
#Graphs for Aircraft Make Fatality Analysis

Make_Analysis_Fig, Make_Analysis_Axes= plt.subplots(nrows= 1, ncols= 2, figsize=(10,4))

Make_Analysis_Axes[0].set_title('Makes With Highest Fatality Rates')
Make_Analysis_Axes[0].set_ylabel('Percentage Of Incidents That Are Fatal')
Make_Analysis_Axes[0].set_xlabel('Aircraft Makes')

Make_Analysis_Axes[1].set_title('Makes With Lowest Fatality Rates')
Make_Analysis_Axes[1].set_ylabel('Percentage Of Incidents That Are Fatal')
Make_Analysis_Axes[1].set_xlabel('Aircraft Makes')

x1= Worst_Performing_Makes['Make']
y1= Worst_Performing_Makes['Make.Fatality.Percentage']

x2= Top_Performing_Makes['Make']
y2= Top_Performing_Makes['Make.Fatality.Percentage']

Make_Analysis_Axes[0].bar(x1, y1, color= 'red')
Make_Analysis_Axes[1].bar(x2, y2, color= 'green')

Make_Analysis_Axes[0].set_xticklabels(x1, rotation=90,)
Make_Analysis_Axes[1].set_xticklabels(x2, rotation=90)

Make_Analysis_Axes[0].legend(['Fatality Percentage'], loc= 'upper left')
Make_Analysis_Axes[1].legend(['Fatality Percentage'], loc= 'upper left')

plt.savefig("./images/Make_Fatality_Distribution.png", dpi=150, bbox_inches='tight')
plt.show()
# Out:
# /var/folders/p_/7g5qyc8d5zv5nfywm65yhpkc0000gn/T/ipykernel_83805/4050005476.py:22: UserWarning: FixedFormatter should only be used together with FixedLocator
#   Make_Analysis_Axes[0].set_xticklabels(x1, rotation=90,)
# /var/folders/p_/7g5qyc8d5zv5nfywm65yhpkc0000gn/T/ipykernel_83805/4050005476.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   Make_Analysis_Axes[1].set_xticklabels(x2, rotation=90)

# %%
#Graphs for Aircraft Model Fatality Analysis

Model_Analysis_Fig, Model_Analysis_Axes= plt.subplots(nrows= 1, ncols= 2, figsize=(10,4))

Model_Analysis_Axes[0].set_title('Models With Highest Fatality Rates')
Model_Analysis_Axes[0].set_ylabel('Percentage Of Incidents That Are Fatal')
Model_Analysis_Axes[0].set_xlabel('Aircraft Models')

Model_Analysis_Axes[1].set_title('Models With Lowest Fatality Rates')
Model_Analysis_Axes[1].set_ylabel('Percentage Of Incidents That Are Fatal')
Model_Analysis_Axes[1].set_xlabel('Aircraft Models')

x1= Worst_Performing_Models['Model']
y1= Worst_Performing_Models['Model.Fatality.Percentage']

x2= Top_Performing_Models['Model']
y2= Top_Performing_Models['Model.Fatality.Percentage']

Model_Analysis_Axes[0].bar(x1, y1, color= 'red')
Model_Analysis_Axes[1].bar(x2, y2, color= 'green')

Model_Analysis_Axes[0].set_xticklabels(x1, rotation=90)
Model_Analysis_Axes[1].set_xticklabels(x2, rotation=90)

Model_Analysis_Axes[0].legend(['Fatality Percentage'], loc= 'upper left')
Model_Analysis_Axes[1].legend(['Fatality Percentage'], loc= 'upper left')

plt.savefig("./images/Model_Fatality_Distribution.png", dpi=150, bbox_inches='tight')
plt.show()
# Out:
# /var/folders/p_/7g5qyc8d5zv5nfywm65yhpkc0000gn/T/ipykernel_83805/784860001.py:22: UserWarning: FixedFormatter should only be used together with FixedLocator
#   Model_Analysis_Axes[0].set_xticklabels(x1, rotation=90)
# /var/folders/p_/7g5qyc8d5zv5nfywm65yhpkc0000gn/T/ipykernel_83805/784860001.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   Model_Analysis_Axes[1].set_xticklabels(x2, rotation=90)

# %%
#####export the relevant dataframes to csv files

# %%
#df.to_csv('file_name.csv')

# %%
Worst_Performing_Models
# Out:
#       Model  Fatality.Count  Model.Count  Model.Fatality.Percentage
# 73     208B              65          182                       36.0
# 85    8Kcab              58          162                       36.0
# 139     208              37          100                       37.0
# 26      R44             132          353                       37.0
# 90     M20K              60          158                       38.0
# 52       58              95          252                       38.0
# 105    421C              51          130                       39.0
# 116    310R              48          118                       41.0
# 119    340A              48          115                       42.0
# 118  95-B55              50          117                       43.0

# %%
Worst_Performing_Models.to_csv('./data/new_data/Worst_Performing_Models.csv')

# %%
Top_Performing_Models
# Out:
#       Model  Fatality.Count  Model.Count  Model.Fatality.Percentage
# 16      737              16          486                        3.0
# 18   G-164A              22          451                        5.0
# 67    Pa-22              12          199                        6.0
# 104   Pa-20               8          130                        6.0
# 131   G-164               6          105                        6.0
# 128   T188C               7          106                        7.0
# 21   G-164B              28          408                        7.0
# 86      170              11          162                        7.0
# 114   A75N1               8          120                        7.0
# 88   Uh-12E              11          159                        7.0

# %%
Top_Performing_Models.to_csv('./data/new_data/Top_Performing_Models.csv')

# %%
Worst_Performing_Makes
# Out:
#                   Make  Fatality.Count  Make.Count  Make.Fatality.Percentage
# 5               Mooney             376        1297                      29.0
# 2                Beech            1575        5302                      30.0
# 49             Learjet              42         135                      31.0
# 32  Cirrus Design Corp              72         223                      32.0
# 21      North American             122         381                      32.0
# 53            Lockheed              38         119                      32.0
# 42              Cirrus              50         150                      33.0
# 51                Vans              45         128                      35.0
# 52              Socata              48         124                      39.0
# 45          Mitsubishi              61         145                      42.0

# %%
Worst_Performing_Makes.to_csv('./data/new_data/Worst_Performing_Makes.csv')

# %%
Top_Performing_Makes
# Out:
#                  Make  Fatality.Count  Make.Count  Make.Fatality.Percentage
# 47               Waco               6         141                       4.0
# 26             Airbus              15         289                       5.0
# 55  Grumman-Schweizer               6         116                       5.0
# 4              Boeing             167        2621                       6.0
# 24             Hiller              23         343                       7.0
# 48                Let              10         135                       7.0
# 43      Balloon Works              10         147                       7.0
# 56              Helio               9         113                       8.0
# 40   Airbus Industrie              12         154                       8.0
# 10          Schweizer              71         757                       9.0

# %%
Top_Performing_Makes.to_csv('./data/new_data/Top_Performing_Makes.csv')

# %%
Significant_Engine_Type_Fatality_Analysis
# Out:
#      Engine.Type  Fatality.Count  Incident.Count  Fatality %
# 0  Reciprocating           13148           68251        5.19
# 1    Turbo Shaft             799            3523        4.41
# 2     Turbo Prop             815            3325        4.08
# 3      Turbo Fan             198            2463       12.44
# 4      Turbo Jet             136             701        5.15

# %%
Significant_Engine_Type_Fatality_Analysis.to_csv('./data/new_data/Significant_Engine_Type_Fatality_Analysis.csv')

# %%
Significant_engine_number_analysis
# Out:
#   Number.of.Engines  Fatality.Count  Incident.Count  Fatality %
# 0                 0             165            1172       14.08
# 1                 1           12758           68215       18.70
# 2                 2            2756           10996       25.06
# 3                 3              24             482        4.98
# 4                 4              56             425       13.18

# %%
Significant_engine_number_analysis.to_csv('./data/new_data/Significant_engine_number_analysis.csv')
